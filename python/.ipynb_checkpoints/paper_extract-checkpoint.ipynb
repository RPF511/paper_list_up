# %%
import os
import re
import numpy
import pandas as pd
# import PyPDF2
import requests
from bs4 import BeautifulSoup
from googlesearch import search

# %%
file = "Quantum_Machine_Learning_for_6G_Communication_Networks:_State-of-the-Art_and_Vision_for_the_Future" 
path = os.getcwd() + "/references/" + file +".txt"
csv_path = os.getcwd() + "/data/" + file +".csv"

# %%
class ResearchPaperList:
    def __init__(self):
        self.paper_data = ["title","author","date",0,"DOI",0,"publisher","url"]     
        self.ref_path = os.getcwd() + "/references/.txt"
        self.csv_path = os.getcwd() + "/data/Research_Paper_Data.csv"
        self.id_path = os.getcwd() + "/data/Research_Paper_List.csv"
        self.link_path = ""
        self.ref_data = ""
        self.link_data = ""
        self.open_id()
        self.open_csv()
    
    def open_id(self):
        if(not os.path.exists(self.id_path)):
            print("csv file not exists")
            return
        self.id_data = pd.read_csv(self.id_path)
        return
    
    def open_csv(self):
        if(not os.path.exists(self.csv_path)):
            print("csv file not exists")
            return False
        self.csv_data = pd.read_csv(self.csv_path, index_col = 0)
        return True
    
    def open_link(self):
        if(not os.path.exists(self.link_path)):
            print("csv file not exists")
            return False
        self.link_data = pd.read_csv(self.link_path, index_col = 0)
        return True
    
    def save_id_data(self):
        self.id_data.to_csv(self.id_path, sep=',', na_rep='NaN', index = False)
        
    def save_csv_data(self):
        self.csv_data.to_csv(self.csv_path,sep=',', na_rep='NaN')
    
    def save_link_data(self):
        self.link_data.to_csv(self.link_path,sep=',', na_rep='NaN')

    def get_id_by_DOI(self,doi):
        result = self.id_data.loc[q1.id_data["DOI"] == doi].values.tolist()
        if(not len(result)):
            return -1
        return result[0][0]

    def create_id(self, doi, title):
        result = [len(self.id_data), doi, title]
        self.id_data.loc[len(self.id_data)] = result
#         self.save_id_data()
        return result[0]

    
    
    def open_ref(self):
        if(not os.path.exists(self.ref_path)):
            print("file not exists")
            return False
        if(self.ref_data):
            self.ref_data.close()
        self.ref_data =  open(self.ref_path,"r", encoding='utf-8') 
        return True
        
    def print_ref(self, head_count = 5000):
        if not self.ref_data:
            self.open_ref()
        if(self.ref_data):
            while True:
                if(head_count == 0) : break
                line = self.ref_data.readline()
                if not line: break
                print(line) 
                head_count -= 1
    
    def close_ref(self):
        if(self.ref_data):
            self.ref_data.close()
            
    def set_data(self, paper_data, reference_list):
        self.paper_data = paper_data
        self.ref_path = os.getcwd() + "/references/" + reference_list +".txt"
        self.open_ref()
        paper_id = self.get_id_by_DOI(paper_data[4])
        if(paper_id == -1):
            paper_id = self.create_id(paper_data[4], paper_data[0])
            print(paper_id)
            self.save_id_data()
        self.link_path = os.getcwd() + "/data/"+ str(paper_id) +".csv"
        if (not self.open_link()):
            self.link_data = pd.DataFrame(columns=["id","title","keywords"])
            self.link_data.loc[0] = [paper_id] + [paper_data[0]] + [""]
            self.csv_data.loc[paper_id] = paper_data + [""]
            self.save_csv_data()
            self.save_link_data()
        
                
    def check_index(self, line,index):
        if(line[0]=="[" and line[1:1+len(str(index))] == str(index)):
            return True
        else:
            return False

    def get_paper_html(self, search_url):
        response = requests.get(search_url)
        if response.status_code == 200:
            html = response.text
            soup = BeautifulSoup(html, 'html.parser')
            return soup
        else:
            return -1

    def get_citations(self, html):
        html = str(html)
        data = 0
        temp = html.split('"citationCount":"')
        if(len(temp)>1):
            data = int(temp[1].split('"')[0])
        return data

    def get_INSPEC(self, html):
        html = str(html)
        data = 0
        temp = html.split('"accessionNumber":"')
        if(len(temp)>1):
            data = int(temp[1].split('"')[0])
        return data

    def get_DOI(self, html):
        html = str(html)
        data = ""
        temp = html.split('"doi":"')
        if(len(temp)>1):
            data = temp[1].split('"')[0]
        return data

    def get_date(self, html):
        html = str(html)
        data = ""
        temp = html.split('"dateOfInsertion":"')
        if(len(temp)>1):
            data = temp[1].split('"')[0]
        return data
        
    def handle_data(self, csv_data, current,index):
        temp = ["","","",0,"",0,"","",""]
        temp_link = [-1,"",""]
        current =current.replace("\n","")
#         print("index ",index,"\n",current)
        parse = re.split('“|”',current)
#         parse = re.split('‘‘|’’',current)
        if(len(parse)<2):
            return
        temp[0] = parse[1][:-1]
        temp_link[1] = temp[0]
        temp[1] = parse[0]
        is_url = False
        if("IEEE" in parse[2]):
            temp[6] = "IEEE"
            for search_url in search(temp[0], tld="co.in", num=5, stop=5, pause=1):
                if('ieee' in search_url):
                    temp[7] = search_url
                    is_url = True
                    break;
        if(is_url):
            html = self.get_paper_html(temp[7])
            temp[4] = self.get_DOI(html)
            temp_link[0] = self.get_id_by_DOI(temp[4])
            if(temp_link[0] == -1):
                temp_link[0] = self.create_id(temp[4], temp[0])
                temp[5] = self.get_citations(html)
                temp[3] = self.get_INSPEC(html)
                temp[2] = self.get_date(html)
                self.csv_data.loc[temp_link[0]] = temp
                
#                 self.save_csv_data()
#                 self.save_id_data()
#                 self.save_link_data()
        print("idx ", index, " ", temp_link, " ", temp)
        self.link_data.loc[index] = temp_link
        

    def extract_reference(self):
        index = 1
        current = ""
        
        while True:
            
            line = self.ref_data.readline()
#             print(line)
            if not line: break
            if(self.check_index(line, index+1)):
                self.handle_data(self.csv_data,current[3+len(str(index)):],index)
                current = line
                index += 1
            else:
                current += line
        self.ref_data.close()
        self.save_id_data()
        self.save_csv_data()
        self.save_link_data()

# %%
q1 = ResearchPaperList()
q1.set_data(["6G Wireless Communication Systems: Applications, Requirements, Technologies, Challenges, and Research Directions",
             "Mostafa Zaman Chowdhury, Md. Shahjalal, Shakil Ahmed, Yeong Min Jang",
             "20 July 2020",
             "19955163",
             "10.1109/OJCOMS.2020.3010270",
             172,
             "IEEE",
             "https://ieeexplore.ieee.org/document/9144301"],
            "ref1")
# q1.set_data(["Quantum machine learning for 6G communica-tion networks: State-of-the-art and vision for the future",
#              "S. J. Nawaz, S. K. Sharma, S. Wyne, M. N. Patwary, andM. Asaduzzaman, ",
#              "15 April 2019",
#              18609246,
#              "10.1109/ACCESS.2019.2909490",
#              170,
#              "IEEE",
#              "https://ieeexplore.ieee.org/document/8681450"],
#             "ref2")
# Out:
# csv file not exists

# %%
print(len(q1.id_data))
# d1 = q1.id_data.loc[q1.id_data["DOI"] == "10.1109/OJCOMS.2020.3010270"].values.tolist()
# print(d1)
print(q1.get_id_by_DOI("10.1109/OJCOMS.20202.3010270"))
# Out:
# 162
# -1

# %%
q1.extract_reference()
# Out:
# idx  1   [1, 'Terahertz communication for vehicular networks']   ['Terahertz communication for vehicular networks', 'S. Mumtaz et al., ', '', 0, '10.1109/TVT.2017.2712878', 0, 'IEEE', 'https://ieeexplore.ieee.org/document/7982949', '']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 q1.extract_reference()
#
# Input In [7], in ResearchPaperList.extract_reference(self)
#     192 if not line: break
#     193 if(self.check_index(line, index+1)):
# --> 194     self.handle_data(self.csv_data,current[3+len(str(index)):],index)
#     195     current = line
#     196     index += 1
#
# Input In [7], in ResearchPaperList.handle_data(self, csv_data, current, index)
#     177 #                 self.save_csv_data()
#     178 #                 self.save_id_data()
#     179 #                 self.save_link_data()
#     180         print("idx ", index, " ", temp_link, " ", temp)
# --> 181         self.link_data.loc[index] = temp_link
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexing.py:716, in _LocationIndexer.__setitem__(self, key, value)
#     713 self._has_valid_setitem_indexer(key)
#     715 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 716 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexing.py:1682, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1679     indexer, missing = convert_missing_indexer(indexer)
#    1681     if missing:
# -> 1682         self._setitem_with_indexer_missing(indexer, value)
#    1683         return
#    1685 # align and set the values
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexing.py:1998, in _iLocIndexer._setitem_with_indexer_missing(self, indexer, value)
#    1995     if is_list_like_indexer(value):
#    1996         # must have conforming columns
#    1997         if len(value) != len(self.obj.columns):
# -> 1998             raise ValueError("cannot set a row with mismatched columns")
#    2000     value = Series(value, index=self.obj.columns, name=indexer)
#    2002 if not len(self.obj):
#    2003     # We will ignore the existing dtypes instead of using
#    2004     #  internals.concat logic
#
# ValueError: cannot set a row with mismatched columns

# %%
# pd.set_option('display.max_rows', 300)
q1.csv_data.head(300)
# Out:
#                                                 title  \
# 0   6G Wireless Communication Systems: Application...
# 1      Terahertz communication for vehicular networks
# 2   Quantum machine learning for 6G communica-tion...
# 3      Toward 6G networks: Use cases and technologies
# 4   5G: A tutorial overview of standards, trials, ...
# 5   Oneintegrated energy efficiency proposal for 5...
# 6   5G backhaulchallenges and emerging research di...
# 7                                     What will 5G be
# 8   6G: The next frontier: From holographic mes-sa...
# 9   A vision of 6G wireless systems:Applications, ...
# 10  6G vision and requirements: Is there anyneed f...
# 11  UAV communications for 5G and beyond:Recent ad...
# 12   Theroadmap to 6G: AI empowered wireless networks
# 13  Artificial intelligence-based resource allocat...
# 14  Interferencemanagement based on RT/nRT traffic...
# 15  Game-based approach for QoS provisioning and i...
# 16  Impact of small cells overlappingon mobility m...
# 17  Joint cell activation and selectionfor green c...
# 18  Future ofultra-dense networks beyond 5G: Harne...
# 19  6G wireless communica-tions: Vision and potent...
# 20  Acomparative survey of optical wireless techno...
# 21  Wireless communications and applicationsabove ...
# 22  Optical wireless hybrid networks: Trends, oppo...
# 23  Human bond communication with head-mounted dis...
# 24  Network topology reconfig-uration for FSO-base...
# 25  Hybridradio/free-space optical design for next...
# 26  Performance analysis of hybrid FSO systems usi...
# 27  Fronthauling for 5G LTE-U ultra dense cloud sm...
# 28  Modified conjugate beam-forming for cell-free ...
# 29  Wireless communications through reconfigurable...
# 30  Blockchain access privacy:Challenges and direc...
# 31  Joint 3D UAV placement andresource allocation ...
# 32  Beyond 5G with UAVs: Foundations of a 3D wirel...
# 33  A surveyon green 6G network: Architecture and ...
# 34  Wireless communicationswith unmanned aerial ve...
# 35  Wireless informationand energy transfer in int...
# 36  AI-assisted network-slicing based next-generat...
# 37  An incentive mechanism integrating jointpower,...
# 38  On the effect of temporal correlation onjoint ...
# 39  Expedited neighbor discovery in direc-tional t...
# 40  The D-OMA method for massivemultiple access in...
# 41  Flexible radio access beyond5G: A future proje...
# 42  Airplane-aided integrated networking for 6G wi...
# 43  6G: Connecting everything by1000 times price r...
# 44  6G:Opening new horizons for integration of com...
# 45  A key 6G challenge and opportunity—Connecting ...
# 46  AI-based joint optimizationof QoS and security...
# 47  Artificial intelligence-enabled cellular netwo...
# 48  Deeplearning-based mmWave beam selection for 5...
# 49  Future intelligent andsecure vehicular network...
# 50  HetMEC:Heterogeneous multi-layer mobile edge c...
#
#                                                author               date  \
# 0   Mostafa Zaman Chowdhury, Md. Shahjalal, Shakil...       20 July 2020
# 1                                  S. Mumtaz et al.,        17 July 2017
# 2   S. J. Nawaz, S. K. Sharma, S. Wyne, M. N. Patw...      15 April 2019
# 3   M. Giordani, M. Polese, M. Mezzavilla, S. Rang...      18 March 2020
# 4                                   M. Shafi et al.,        02 June 2017
# 5   D. Zhang, Z. Zhou, S. Mumtaz, J. Rodriguez, an...        23 May 2017
# 6   M. Jaber, M. A. Imran, R. Tafazolli, and A. Tu...        23 May 2017
# 7                              J. G. Andrews et al.,        22 July 2014
# 8                             E. C. Strinati et al.,      20 August 2019
# 9                   W. Saad, M. Bennis, and M. Chen,        02 June 2020
# 10                           K. David and H. Berndt,      30 August 2018
# 11                      B. Li, Z. Fei, and Y. Zhang,         08 May 2019
# 12  K. B. Letaief, W. Chen, Y. Shi, J. Zhang, and ...     21 August 2019
# 13  H. Zhang, M. Feng, K. Long, G. K. Karagiannidi...   20 November 2019
# 14    M. Z. Chowdhury, M. T. Hossan, and Y. M. Jang,        29 June 2018
# 15  A. S. M. Zadid Shifat, M. Z. Chowdhury, and Y....      13 March 2018
# 16                A. J. Mahbas, H. Zhu, and J. Wang,         06 May 2019
# 17             T. Zhou, N. Jiang, Z. Liu, and C. Li,    14 February 2018
# 18  S. Andreev, V. Petrov, M. Dohler, and H. Yanik...       18 June 2019
# 19             P. Yang, Y. Xiao, M. Xiao, and S. Li,        31 July 2019
# 20  M. Z. Chowdhury, M. T. Hossan, A. Islam, and Y...      13 March 2018
# 21                           T. S. Rappaport et al.,        25 June 2019
# 22  M. Z. Chowdhury, M. K. Hasan, M. Shahjalal, M....        27 May 2020
# 23  M. T. Hossan, M. Z. Chowdhury, M. Shahjalal, a...   21 February 2019
# 24       Z. Gu, J. Zhang, Y. Ji, L. Bai, and X. Sun,    04 December 2018
# 25  A. Douik, H. Dahrouj, T. Y. Al-Naffouri, and M...       14 June 2016
# 26  B. Bag, A. Das, I. S. Ansari, A. Prokeš, C. Bo...       26 June 2018
# 27  H. Zhang, Y. Dong, J. Cheng, M. J. Hossain, an...    10 January 2017
# 28         M. Attarifar, A. Abbasfar, and A. Lozano,         06 May 2019
# 29  E. Basar, M. Di Renzo, J. de Rosny, M. Debbah,...     28 August 2019
# 30               R. Henry, A. Herzberg, and A. Kate,      06 August 2018
# 31          C. Pan, J. Yi, C. Yin, J. Yu, and X. Li,      08 August 2019
# 32  M. Mozaffari, A. T. Z. Kasgari, W. Saad, M. Be...    08 January 2019
# 33  T. Huang, W. Yang, J. Wu, J. Ma, X. Zhang, and...   12 December 2019
# 34                 Y. Zeng, R. Zhang, and T. J. Lim,         18 May 2016
# 35          H. Wang, W. Wang, X. Chen, and Z. Zhang,    12 February 2015
# 36                                   X. Shen et al.,    03 February 2020
# 37                      C. Yi, S. Huang, and J. Cai,       05 March 2018
# 38                         M. Salehi and E. Hossain,    09 December 2019
# 39                          Q. Xia and J. M. Jornet,      13 August 2019
# 40                      Y. Al-Eryani and E. Hossain,      19 August 2019
# 41          Z. E. Ankarali, B. Peköz, and H. Arslan,   26 September 2017
# 42  X. Huang, J. A. Zhang, R. P. Liu, Y. J. Guo, a...     19 August 2019
# 43                    S. Zhang, C. Xiang, and S. Xu,       30 April 2020
# 44  G. Gui, M. Liu, F. Tang, N. Kato, and F. Adachi,     28 October 2020
# 45                        E. Yaacoub and M. Alouini,       13 April 2020
# 46                 B. Mao, Y. Kawamoto, and N. Kato,      12 August 2020
# 47  R. Shafin, L. Liu, V. Chandrasekhar, H. Chen, ...        13 May 2020
# 48  M. S. Sim, Y. Lim, S. H. Park, L. Dai, and C. ...      19 March 2020
# 49        F. Tang, Y. Kawamoto, N. Kato, and J. Liu,     23 January 2020
# 50    Y. Zhang, B. Di, P. Wang, J. Lin, and L. Song,       16 April 2020
#
#       INSPEC                          DOI  citations publisher  \
# 0   19955163  10.1109/OJCOMS.2020.3010270        172      IEEE
# 1   17026925     10.1109/TVT.2017.2712878        107      IEEE
# 2   18609246  10.1109/ACCESS.2019.2909490        170      IEEE
# 3   19469688     10.1109/MCOM.001.1900411        378      IEEE
# 4   16915203    10.1109/JSAC.2017.2692307       1048      IEEE
# 5   16585155    10.1109/JIOT.2016.2599852         72      IEEE
# 6   15977764  10.1109/ACCESS.2016.2556011        347      IEEE
# 7   14469237    10.1109/JSAC.2014.2328098       5571      IEEE
# 8   18920911     10.1109/MVT.2019.2921162        193      IEEE
# 9   19669258     10.1109/MNET.001.1900287        866      IEEE
# 10  18058905     10.1109/MVT.2018.2848498        245      IEEE
# 11  18653884    10.1109/JIOT.2018.2887086        411      IEEE
# 12  18937666    10.1109/MCOM.2019.1900271        554      IEEE
# 13         0     10.1109/MVT.2019.2938328         12      IEEE
# 14  17905713  10.1109/ACCESS.2018.2844843         12      IEEE
# 15  17627839  10.1109/ACCESS.2017.2704094         11      IEEE
# 16  18470423     10.1109/TWC.2018.2889465         10      IEEE
# 17  17573777  10.1109/ACCESS.2017.2780818         29      IEEE
# 18  18757658    10.1109/MCOM.2019.1800056         60      IEEE
# 19  18881530    10.1109/MNET.2019.1800418        295      IEEE
# 20  17649076  10.1109/ACCESS.2018.2792419        218      IEEE
# 21  18770124  10.1109/ACCESS.2019.2921522        539      IEEE
# 22  19649690   10.1109/COMST.2020.2966855         55      IEEE
# 23  18470651    10.1109/MCOM.2018.1800527         14      IEEE
# 24  18495784  10.1109/ACCESS.2018.2880880         25      IEEE
# 25  16073095   10.1109/TCOMM.2016.2557789         48      IEEE
# 26  17867553   10.1109/JPHOT.2018.2837356         44      IEEE
# 27  16597965   10.1109/MWC.2016.1600066WC        186      IEEE
# 28  18598658     10.1109/LWC.2018.2890470         36      IEEE
# 29  18929395  10.1109/ACCESS.2019.2935192        718      IEEE
# 30  18023283     10.1109/MSP.2018.3111245        106      IEEE
# 31  18880599  10.1109/ACCESS.2019.2927521         19      IEEE
# 32  18392491     10.1109/TWC.2018.2879940        196      IEEE
# 33  19177825  10.1109/ACCESS.2019.2957648        124      IEEE
# 34  16002751    10.1109/MCOM.2016.7470933       1894      IEEE
# 35  14919258  10.1109/GLOCOM.2014.7037192         19      IEEE
# 36  19387591    10.1109/OJVT.2020.2965100         90      IEEE
# 37  17630120     10.1109/TMC.2017.2741481         49      IEEE
# 38  19195545     10.1109/LWC.2019.2932435          4      IEEE
# 39  18905432     10.1109/TVT.2019.2924820         23      IEEE
# 40  18905206     10.1109/MVT.2019.2919279         39      IEEE
# 41  17246407  10.1109/ACCESS.2017.2684783        122      IEEE
# 42  18905209     10.1109/MVT.2019.2921244         67      IEEE
# 43  19582160    10.1109/OJVT.2020.2980003         30      IEEE
# 44  20095341      10.1109/MWC.001.1900516        183      IEEE
# 45  19527855   10.1109/JPROC.2020.2976703         75      IEEE
# 46  19869379    10.1109/JIOT.2020.2982417         46      IEEE
# 47  19590614      10.1109/MWC.001.1900323         69      IEEE
# 48  19464155  10.1109/ACCESS.2020.2980285         51      IEEE
# 49  19296586   10.1109/JPROC.2019.2954595        191      IEEE
# 50  19626198     10.1109/TVT.2020.2975559         26      IEEE
#
#                                                   url keywords
# 0        https://ieeexplore.ieee.org/document/9144301      NaN
# 1        https://ieeexplore.ieee.org/document/7982949      NaN
# 2        https://ieeexplore.ieee.org/document/8681450
# 3   https://ieeexplore.ieee.org/abstract/document/...      NaN
# 4        https://ieeexplore.ieee.org/document/7894280      NaN
# 5        https://ieeexplore.ieee.org/document/7542566      NaN
# 6         http://ieeexplore.ieee.org/document/7456186      NaN
# 7        https://ieeexplore.ieee.org/document/6824752      NaN
# 8        https://ieeexplore.ieee.org/document/8792135      NaN
# 9        https://ieeexplore.ieee.org/document/8869705      NaN
# 10       https://ieeexplore.ieee.org/document/8412482      NaN
# 11       https://ieeexplore.ieee.org/document/8579209      NaN
# 12       https://ieeexplore.ieee.org/document/8808168      NaN
# 13       https://ieeexplore.ieee.org/document/8871153      NaN
# 14       https://ieeexplore.ieee.org/document/8400388      NaN
# 15       https://ieeexplore.ieee.org/document/7936481      NaN
# 16       https://ieeexplore.ieee.org/document/8605528      NaN
# 17       https://ieeexplore.ieee.org/document/8169674      NaN
# 18       https://ieeexplore.ieee.org/document/8722593      NaN
# 19       https://ieeexplore.ieee.org/document/8782879      NaN
# 20       https://ieeexplore.ieee.org/document/8259465      NaN
# 21       https://ieeexplore.ieee.org/document/8732419      NaN
# 22        http://ieeexplore.ieee.org/document/8960379      NaN
# 23       https://ieeexplore.ieee.org/document/8647107      NaN
# 24       https://ieeexplore.ieee.org/document/8532444      NaN
# 25       https://ieeexplore.ieee.org/document/7458183      NaN
# 26       https://ieeexplore.ieee.org/document/8360015      NaN
# 27       https://ieeexplore.ieee.org/document/7811838      NaN
# 28       https://ieeexplore.ieee.org/document/8599043      NaN
# 29       https://ieeexplore.ieee.org/document/8796365      NaN
# 30       https://ieeexplore.ieee.org/document/8425613      NaN
# 31  https://ieeexplore.ieee.org/abstract/document/...      NaN
# 32  https://ieeexplore.ieee.org/iel7/7693/8605558/...      NaN
# 33       https://ieeexplore.ieee.org/document/8922617      NaN
# 34       https://ieeexplore.ieee.org/document/7470933      NaN
# 35  https://ieeexplore.ieee.org/document/7037192?a...      NaN
# 36       https://ieeexplore.ieee.org/document/8954683      NaN
# 37       https://ieeexplore.ieee.org/document/8013127      NaN
# 38       https://ieeexplore.ieee.org/document/8784235      NaN
# 39       https://ieeexplore.ieee.org/document/8746670      NaN
# 40       http://ieeexplore.ieee.org/document/8760269/      NaN
# 41       http://ieeexplore.ieee.org/document/7883931/      NaN
# 42       https://ieeexplore.ieee.org/document/8760401      NaN
# 43       https://ieeexplore.ieee.org/document/9034074      NaN
# 44       https://ieeexplore.ieee.org/document/9023459      NaN
# 45       https://ieeexplore.ieee.org/document/9042251      NaN
# 46       https://ieeexplore.ieee.org/document/9044345      NaN
# 47       http://ieeexplore.ieee.org/document/9040202/      NaN
# 48  https://ieeexplore.ieee.org/abstract/document/...      NaN
# 49       https://ieeexplore.ieee.org/document/8926369      NaN
# 50       https://ieeexplore.ieee.org/document/9006930      NaN
