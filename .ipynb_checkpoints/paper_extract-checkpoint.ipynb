# %%
import os
import re
import numpy
import pandas as pd
# import PyPDF2
import requests
from bs4 import BeautifulSoup
from googlesearch import search

# %%
base_url = "https://ieeexplore.ieee.org/search/searchresult.jsp"
file = "Quantum_Machine_Learning_for_6G_Communication_Networks:_State-of-the-Art_and_Vision_for_the_Future" 
path = os.getcwd() + "/references/" + file +".txt"
csv_path = os.getcwd() + "/data/" + file +".csv"

# %%
class ResearchPaperList:
    def __init__(self, url="" , title = ""):
        self.base_url = url
        self.title = title
        self.path = os.getcwd() + "/references/" + title +".txt"
        self.csv_path = os.getcwd() + "/data/" + title +".csv"
        self.csv_data = ""
        self.ref_data = ""
    
    def open_csv(self):
        if(not os.path.exists(self.csv_path)):
            print("csv file not exists")
            return
        self.csv_data = pd.read_csv(self.csv_path, index_col = 0)
    
    def open_ref(self):
        if(not os.path.exists(self.path)):
            print("file not exists")
            return
        if(self.ref_data):
            self.ref_data.close()
        self.ref_data =  open(path,"r", encoding='utf-8') 
        
    def print_ref(self, head_count = 5000):
        if not self.ref_data:
            self.open_ref()
        if(self.ref_data):
            while True:
                if(head_count == 0) : break
                line = self.ref_data.readline()
                if not line: break
                print(line) 
                head_count -= 1
    
    def close_ref(self):
        if(self.ref_data):
            self.ref_data.close()
            
    def set_data(self, url="", title=""):
        self.base_url = url
        self.title = title
        self.path = os.getcwd() + "/references/" + title +".txt"
        self.csv_path = os.getcwd() + "/data/" + title +".csv"
        self.open_csv()
        self.open_ref()
        
    def check_index(self, line,index):
        if(line[0]=="[" and line[1:1+len(str(index))] == str(index)):
            return True
        else:
            return False

    def get_paper_html(self, search_url):
        response = requests.get(search_url)
        if response.status_code == 200:
            html = response.text
            soup = BeautifulSoup(html, 'html.parser')
            return soup
        else:
            return -1

    def get_citations(self, html):
        html = str(html)
        data = 0
        temp = html.split('"citationCount":"')
        if(len(temp)>1):
            data = int(temp[1].split('"')[0])
        return data

    def get_INSPEC(self, html):
        html = str(html)
        data = 0
        temp = html.split('"accessionNumber":"')
        if(len(temp)>1):
            data = int(temp[1].split('"')[0])
        return data

    def get_DOI(self, html):
        html = str(html)
        data = ""
        temp = html.split('"doi":"')
        if(len(temp)>1):
            data = temp[1].split('"')[0]
        return data

    def get_date(self, html):
        html = str(html)
        data = ""
        temp = html.split('"dateOfInsertion":"')
        if(len(temp)>1):
            data = temp[1].split('"')[0]
        return data
        
    def handle_data(self, csv_data, current,index):
        temp = ["","","",0,"",0,"",""]
        current =current.replace("\n","")
    #     print("index ",index,"\n",current)
    #     parse = re.split('“|”',current)
        parse = re.split('‘‘|’’',current)
        if(len(parse)<2):
            return
        temp[0] = parse[1][:-1]
        temp[1] = parse[0]
        is_url = False
        if("IEEE" in parse[2]):
            temp[6] = "IEEE"
            for search_url in search(temp[0], tld="co.in", num=5, stop=5, pause=1):
                if('ieee' in search_url):
                    temp[7] = search_url
                    is_url = True
                    break;
        if(is_url):
            
            html = self.get_paper_html(temp[7])
            temp[5] = self.get_citations(html)
            temp[3] = self.get_INSPEC(html)
            temp[4] = self.get_DOI(html)
            temp[2] = self.get_date(html)
        print("idx ",index," ",temp)
        self.csv_data.loc[index] = temp
        

    def extract_reference(self):
        index = 1
        
        current = ""
        while True:
            
            line = self.ref_data.readline()
            if not line: break
            if(self.check_index(line, index+1)):
    #             print("here")
                self.handle_data(self.csv_data,current[3+len(str(index)):],index)
                current = line
                index += 1
            else:
                current += line
        self.ref_data.close()
    
    def save_csv_data(self):
        self.csv_data.to_csv(csv_path,sep=',', na_rep='NaN')

# %%
q1 = ResearchPaperList()
q1.set_data(base_url, file)

# %%
q1.extract_reference()
# Out:
# idx  2   ['A survey of 5G network: Architecture andemerging technologies', 'A. Gupta and E. R. K. Jha, ', '07 August 2015', 15351996, '10.1109/ACCESS.2015.2461602', 1315, 'IEEE', 'https://ieeexplore.ieee.org/document/7169508']
# idx  3   ['Towards massive connectivity support for scal-able mMTC communications in 5G networks', 'C. Bockelmann et al., ', '18 June 2018', 17829625, '10.1109/ACCESS.2018.2837382', 131, 'IEEE', 'http://ieeexplore.ieee.org/document/8360103/']
# idx  4   ['Towards massive machinetype communications in ultra-dense cellular IoT networks: Currentissues and machine learning-assisted solutions', 'S. K. Sharma and X. Wang. (Aug. 2018). ', '', 0, '', 0, '', '']
# idx  5   ['Open issues and beyond 5G', 'M. Chiani, E. Paolini, and F. Callegati, ', '', 0, '', 0, '', '']
# idx  6   ['6G vision and requirements: Is there any needfor beyond 5G', 'K. David and H. Berndt, ', '30 August 2018', 18058905, '10.1109/MVT.2018.2848498', 250, 'IEEE', 'https://ieeexplore.ieee.org/document/8412482']
# idx  7   ['A speculative study on 6G', 'F. Tariq, M. Khandaker, K.-K. Wong, M. Imran, M. Bennis, andM. Debbah. (Feb. 2019). ', '', 0, '', 0, '', '']
# idx  8   ['6G: The next frontier', 'E. C. Strinati, S. Barbarossa, J. L. Gonzalez-Jimenez, D. Kténas,N. Cassiau, and C. Dehos. (2019). ', '', 0, '', 0, '', '']
# idx  9   ['A vision of 6Gwireless systems: Applications, trends, technologies, and open researchproblems', 'W. Saad, M. Bennis, and M. Chen. (Mar. 2019). ', '', 0, '', 0, '', '']
# idx  11   ['Thirty years of machine learning: The road to Pareto-optimal next-generation wireless networks', 'J. Wang, C. Jiang, H. Zhang, Y. Ren, K.-C. Chen, and L. Hanzo.(2019). ', '', 0, '', 0, '', '']
# idx  12   ['Big data analytics, machine learning, and artificial intelligence in next-generation wireless networks', 'M. G. Kibria, K. Nguyen, G. P. Villardi, O. Zhao, K. Ishizu, and F. Kojima,', '28 June 2018', 17905641, '10.1109/ACCESS.2018.2837692', 184, 'IEEE', 'https://ieeexplore.ieee.org/document/8360430']
# idx  13   ['When machine learningmeets big data: A wireless communication perspective', 'Y. Liu, S. Bi, Z. Shi, and L. Hanzo. (2019). ', '', 0, '', 0, '', '']
# idx  14   ['Collaborative distributed Q-learning forRACH congestion minimization in cellular IoT networks', 'S. K. Sharma and X. Wang, ', '06 May 2019', 18595867, '10.1109/LCOMM.2019.2896929', 36, 'IEEE', 'https://ieeexplore.ieee.org/document/8632974']
# idx  15   ['A very brief introduction to machine learning with appli-cations to communication systems', 'O. Simeone, ', '20 December 2018', 0, '10.1109/TCCN.2018.2881442', 184, 'IEEE', 'https://ieeexplore.ieee.org/document/8542764']
# idx  16   ['Deep learning inmobile and wireless networking: A survey', 'C. Zhang, P. Patras, and H. Haddadi. (2018). ', '', 0, '', 0, '', '']
# idx  17   ['Wireless networksdesign in the era of deep learning: Model-based, AI-based, or both', 'A. Zappone, M. Di Renzo, and M. Debbah. (2019). ', '', 0, '', 0, '', '']
# idx  18   ['Channelagnostic end-to-end learning based communication systems with condi-tional GAN', 'H. Ye, G. Y. Li, B.-H. F. Juang, and K. Sivanesan. (2018). ', '', 0, '', 0, '', '']
# idx  19   ['An introduction to deep learning for the physi-cal layer', 'T. O’Shea and J. Hoydis, ', '19 December 2017', 17525661, '10.1109/TCCN.2017.2758370', 1063, 'IEEE', 'https://ieeexplore.ieee.org/document/8054694']
# idx  20   ['Power of deep learning for channelestimation and signal detection in OFDM systems', 'H. Ye, G. Y. Li, and B.-H. Juang, ', '16 February 2018', 17595984, '10.1109/LWC.2017.2757490', 687, 'IEEE', 'https://ieeexplore.ieee.org/document/8052521']
# idx  21   ['Deep reinforcement learning for resource allocationin V2V communications', 'H. Ye and G. Y. Li, ', '31 July 2018', 17971374, '10.1109/ICC.2018.8422586', 86, 'IEEE', 'http://ieeexplore.ieee.org/document/8422586/']
# idx  22   ['Propagationchannels for mmWave vehicular communications: State-of-the-art andfuture research directions', 'F. Jameel, S. Wyne, S. J. Nawaz, and Z. Chang, ', '13 February 2019', 18469754, '10.1109/MWC.2018.1800174', 42, 'IEEE', 'https://ieeexplore.ieee.org/iel7/7742/7593426/08594703.pdf']
# idx  23   ['Deep learning-basedchannel estimation for beamspace mmWave massive MIMO systems', 'H. He, C.-K. Wen, S. Jin, and G. Y. Li. (2018). ', '', 0, '', 0, '', '']
# idx  24   ['Machine learningfor vehicular networks: Recent advances and application examples', 'H. Ye, L. Liang, G. Y. Li, J. Kim, L. Lu, and M. Wu, ', '21 May 2018', 17768300, '10.1109/MVT.2018.2811185', 149, 'IEEE', 'https://ieeexplore.ieee.org/document/8345672']
# idx  25   ['Deep learningconvolutional neural networks for radio identification', 'S. Riyaz, K. Sankhe, S. Ioannidis, and K. Chowdhury, ', '17 September 2018', 18094844, '10.1109/MCOM.2018.1800153', 112, 'IEEE', 'https://ieeexplore.ieee.org/document/8466371']
# idx  26   ['On a novel deep-learning-based intelligent partially overlapping channel assignment inSDN-IoT', 'F. Tang, B. Mao, Z. M. Fadlullah, and N. Kato, ', '17 September 2018', 18094850, '10.1109/MCOM.2018.1701227', 71, 'IEEE', 'https://ieeexplore.ieee.org/document/8466360']
# idx  27   ['Enabling cognitive smart citiesusing big data and machine learning: Approaches and challenges', 'M. Mohammadi and A. Al-Fuqaha, ', '13 February 2018', 17578019, '10.1109/MCOM.2018.1700298', 153, 'IEEE', 'https://ieeexplore.ieee.org/document/8291121']
# idx  28   ['Quantum computing is exciting and important-really', 'C. Day, ', '', 0, '', 0, '', '']
# idx  29   ['A survey on quantum computing technol-ogy', 'L. Gyongyosi and S. Imre, ', '', 0, '', 0, '', '']
# idx  30   ['Quantum algorithms for wireless communications', 'P. Botsinis et al., ', '31 May 2019', 18726267, '10.1109/COMST.2018.2882385', 34, 'IEEE', 'https://ieeexplore.ieee.org/document/8540839']
# idx  31   ['The quantum dynamic capacity for-mula of a quantum channel', 'M. M. Wilde and M.-H. Hsieh, ', '', 0, '', 0, '', '']
# idx  32   ['EXIT-chart aided quantum code design improvesthe normalised throughput of realistic quantum devices', 'H. V. Nguyen et al., ', '06 May 2019', 16606904, '10.1109/ACCESS.2016.2591910', 20, 'IEEE', 'https://ieeexplore.ieee.org/document/7515170']
# idx  33   ['Quantum-aided multi-objective routing optimizationusing back-tracing-aided dynamic programming', 'D. Alanis et al., ', '06 May 2019', 17991417, '10.1109/TVT.2018.2822626', 4, 'IEEE', 'http://ieeexplore.ieee.org/document/8329527/']
# idx  34   ['Quantum turbo decoding for quantum channelsexhibiting memory', 'M. A. M. Izhar et al., ', '06 May 2019', 17649172, '10.1109/ACCESS.2018.2808373', 3, 'IEEE', 'https://ieeexplore.ieee.org/abstract/document/8299427/']
# idx  35   ['Quantum-assisted indoor localization for uplink mm-Wave and downlink visible light communication systems', 'P. Botsinis et al., ', '06 May 2019', 17381089, '10.1109/ACCESS.2017.2733557', 12, 'IEEE', 'http://ieeexplore.ieee.org/document/7997701/']
# idx  36   ['Quantum-assisted joint multi-objective routing and load balancing forsocially-aware networks', 'D. Alanis, J. Hu, P. Botsinis, Z. Babar, S. X. Ng, and L. Hanzo,', '06 May 2019', 16606979, '10.1109/ACCESS.2016.2629671', 11, 'IEEE', 'https://ieeexplore.ieee.org/document/7745885']
# idx  37   ['Joint quantum-assisted channel estimation and data detection', 'P. Botsinis, D. Alanis, Z. Babar, S. X. Ng, and L. Hanzo, ', '06 May 2019', 16470581, '10.1109/ACCESS.2016.2591903', 13, 'IEEE', 'http://ieeexplore.ieee.org/abstract/document/7515148/']
# idx  38   ['Quantum-aided multi-user transmission innon-orthogonal multiple access systems', 'P. Botsinis et al., ', '06 May 2019', 16470590, '10.1109/ACCESS.2016.2591904', 20, 'IEEE', 'https://ieeexplore.ieee.org/document/7515210']
# idx  39   ['A future with quantum machine learning', 'E. P. DeBenedictis, ', '', 0, '', 0, '', '']
# idx  40   ['Universal discriminative quantum neural networks', 'H. Chen, L. Wossnig, S. Severini, H. Neven, and M. Mohseni. (2018).', '', 0, '', 0, '', '']
# idx  41   ['Quantum machine learning', 'J. Biamonte, P. Wittek, N. Pancotti, P. Rebentrost, N. Wiebe, and S. Lloyd,', '', 0, '', 0, '', '']
# idx  42   ['Quantum algorithmsfor supervised and unsupervised machine learning', 'S. Lloyd, M. Mohseni, and P. Rebentrost. (2013). ', '', 0, '', 0, '', '']
# idx  43   ['Quantum-enhanced machinelearning', 'V. Dunjko, J. M. Taylor, and H. J. Briegel, ', '', 0, '', 0, '', '']
# idx  45   ['5G: A tutorial overview of standards, trials, challenges,deployment, and practice', 'M. Shafi et al., ', '02 June 2017', 16915203, '10.1109/JSAC.2017.2692307', 1044, 'IEEE', 'https://ieeexplore.ieee.org/document/7894280']
# idx  46   ['What will 5G be', 'J. G. Andrews et al., ', '22 July 2014', 14469237, '10.1109/JSAC.2014.2328098', 5490, 'IEEE', 'https://ieeexplore.ieee.org/document/6824752']
# idx  47   ['Millimeter-wave communication with out-of-band information', 'N. Gonzalez-Prelcic, A. Ali, V. Va, and R. W. Heath, Jr., ', '13 December 2017', 17446971, '10.1109/MCOM.2017.1700207', 53, 'IEEE', 'http://ieeexplore.ieee.org/document/8198818']
# idx  48   ['Energy and spectral effi-ciency of very large multiuser MIMO systems', 'H. Q. Ngo, E. G. Larsson, and T. L. Marzetta, ', '07 May 2013', 13487669, '10.1109/TCOMM.2013.020413.110848', 2011, 'IEEE', 'https://ieeexplore.ieee.org/document/6457363']
# idx  49   ['Optimal cell load and throughput in green small cellnetworks with generalized cell association', 'C. Liu and L. Wang, ', '19 May 2016', 16003650, '10.1109/JSAC.2016.2520218', 53, 'IEEE', 'https://ieeexplore.ieee.org/document/7389350']
# idx  51   ['Network function virtualization: State-of-the-art andresearch challenges', 'R. Mijumbi, J. Serrat, J.-L. Gorricho, N. Bouten, F. De Turck, andR. Boutaba, ', '23 May 2017', 15730368, '10.1109/COMST.2015.2477041', 1095, 'IEEE', 'https://ieeexplore.ieee.org/document/7243304']
# idx  52   ['Network slicing and softwarization: A survey on principles, enablingtechnologies, and solutions', 'I. Afolabi, T. Taleb, K. Samdanis, A. Ksentini, and H. Flinck,', '21 August 2018', 18075844, '10.1109/COMST.2018.2815638', 441, 'IEEE', 'https://ieeexplore.ieee.org/abstract/document/8320765']
# idx  53   ['Mobile edge com-puting: A survey', 'N. Abbas, Y. Zhang, A. Taherkordi, and T. Skeie, ', '09 February 2018', 17577583, '10.1109/JIOT.2017.2750180', 941, 'IEEE', 'https://ieeexplore.ieee.org/document/8030322']
# idx  54   ['Intelligent 5G: When cellular networks meet artificialintelligence', 'R. Li et al., ', '27 October 2017', 17288679, '10.1109/MWC.2017.1600304WC', 278, 'IEEE', 'https://ieeexplore.ieee.org/document/7886994']
# idx  55   ['Live data analytics with collaborative edgeand cloud processing in wireless IoT networks', 'S. K. Sharma and X. Wang, ', '24 April 2017', 16811571, '10.1109/ACCESS.2017.2682640', 143, 'IEEE', 'https://ieeexplore.ieee.org/document/7882669']
# idx  56   ['5G-enabledtactile Internet', 'M. Simsek, A. Aijaz, M. Dohler, J. Sachs, and G. Fettweis, ', '10 March 2016', 15840278, '10.1109/JSAC.2016.2525398', 505, 'IEEE', 'https://ieeexplore.ieee.org/document/7403840']
# idx  57   ['A guide to wireless networking bylight', 'H. Haas, C. Chen, and D. O’Brien, ', '', 0, '', 0, '', '']
# idx  58   ['Dynamic spectrum sharing in 5G wireless networks withfull-duplex technology: Recent advances and research challenges', 'S. K. Sharma, T. E. Bogale, L. B. Le, S. Chatzinotas, X. Wang, andB. Ottersten, ', '23 February 2018', 17599758, '10.1109/COMST.2017.2773628', 113, 'IEEE', 'https://ieeexplore.ieee.org/document/8110617']
# idx  59   ['UAV trajectory optimization for data offloading atthe edge of multiple cells', 'F. Cheng et al., ', '16 July 2018', 17932950, '10.1109/TVT.2018.2811942', 199, 'IEEE', 'https://ieeexplore.ieee.org/document/8309339']
# idx  60   ['Spatialspectrum sharing for satellite and terrestrial communication networks', 'C. Zhang, C. Jiang, L. Kuang, J. Jin, Y. He, and Z. Han, ', '07 June 2019', 18737032, '10.1109/TAES.2018.2889585', 28, 'IEEE', 'https://ieeexplore.ieee.org/document/8633412']
# idx  61   ['Analysis of spectrum occupancy usingmachine learning algorithms', 'F. Azmat, Y. Chen, and N. Stocks, ', '15 September 2016', 16316592, '10.1109/TVT.2015.2487047', 61, 'IEEE', 'https://ieeexplore.ieee.org/document/7289481']
# idx  62   ['A survey of energy-efficient techniques for 5G networks and challengesahead', 'S. Buzzi, C.-L. I, T. E. Klein, H. V. Poor, C. Yang, and A. Zappone,', '10 May 2016', 15985567, '10.1109/JSAC.2016.2550338', 460, 'IEEE', 'https://ieeexplore.ieee.org/document/7446253']
# idx  63   ['A new wireless communication paradigm through software-controlled metasurfaces', 'C. Liaskos, S. Nie, A. Tsioliaridou, A. Pitsillides, S. Ioannidis, andI. Akyildiz, ', '17 September 2018', 18128617, '10.1109/MCOM.2018.1700659', 400, 'IEEE', 'https://ieeexplore.ieee.org/document/8466374']
# idx  65   ['Simultaneous wireless information and power transfer (SWIPT):Recent advances and future challenges', 'T. D. P. Perera, D. N. K. Jayakody, S. K. Sharma, S. Chatzinotas, andJ. Li, ', '23 February 2018', 17599764, '10.1109/COMST.2017.2783901', 378, 'IEEE', 'https://ieeexplore.ieee.org/document/8214104']
# idx  66   ['Proactive content caching byexploiting transfer learning for mobile edge computing', 'T. Hou, G. Feng, S. Qin, and W. Jiang, ', '15 January 2018', 17506199, '10.1109/GLOCOM.2017.8254636', 42, 'IEEE', 'https://ieeexplore.ieee.org/document/8254636']
# idx  67   ['Mobility-aware edge caching and computingin vehicle networks: A deep reinforcement learning', 'L. T. Tan and R. Q. Hu, ', '12 November 2018', 18246142, '10.1109/TVT.2018.2867191', 185, 'IEEE', 'http://ieeexplore.ieee.org/document/8447267/']
# idx  68   ['A wireless optical backhaul solutionfor optical attocell networks', 'H. Kazemi, M. Safari, and H. Haas, ', '11 February 2019', 18470404, '10.1109/TWC.2018.2883465', 20, 'IEEE', 'https://ieeexplore.ieee.org/document/8558716']
# idx  69   ['Shared access satellite-terrestrial reconfigurable back-haul network enabled by smart antennas at mmwave band', 'X. Artiga et al., ', '27 September 2018', 18129595, '10.1109/MNET.2018.1800030', 16, 'IEEE', 'https://ieeexplore.ieee.org/document/8473481']
# idx  70   ['Distributed caching enabled peak trafficreduction in ultra-dense IoT networks', 'S. K. Sharma and X. Wang, ', '08 June 2018', 17838960, '10.1109/LCOMM.2018.2810211', 12, 'IEEE', 'http://ieeexplore.ieee.org/abstract/document/8303180/']
# idx  71   ['A surveyof physical layer security techniques for 5G wireless networks and chal-lenges ahead', 'Y. Wu, A. Khisti, C. Xiao, G. Caire, K.-K. Wong, and X. Gao, ', '09 July 2018', 17932626, '10.1109/JSAC.2018.2825560', 326, 'IEEE', 'https://ieeexplore.ieee.org/document/8335290']
# idx  72   ['Machine learning and deep learning methods for cyberse-curity', 'Y. Xin et al., ', '16 July 2018', 17905844, '10.1109/ACCESS.2018.2836950', 324, 'IEEE', 'https://ieeexplore.ieee.org/document/8359287']
# idx  73   ['Lightweight quantum encryption forsecure transmission of power data in smart grid', 'Y. Li, P. Zhang, and R. Huang, ', '28 March 2019', 18559602, '10.1109/ACCESS.2019.2893056', 16, 'IEEE', 'https://ieeexplore.ieee.org/document/8620559']
# idx  74   ['Neural network basedMIMO-OFDM channel equalizer using comb-type pilot arrangement', 'S. J. Nawaz, S. Mohsin, and A. A. Ikaram, ', '04 August 2009', 10804477, '10.1109/ICFCC.2009.136', 14, 'IEEE', 'http://ieeexplore.ieee.org/abstract/document/5189738/']
# idx  75   ['Learning assisted estimation for time- vary-ing channels', 'X. Ma, H. Ye, and Y. Li, ', '', 0, '', 0, '', '']
# idx  76   ['Airborne Internet access through submarine optical fiber cables', 'S. J. Nawaz, N. M. Khan, M. I. Tiwana, N. Hassan, and S. I. Shah,', '07 April 2015', 15038599, '10.1109/TAES.2014.130416', 13, 'IEEE', 'https://ieeexplore.ieee.org/document/7073483']
# idx  77   ['Echo state networks forproactive caching in cloud-based radio access networks with mobileusers', 'M. Chen, W. Saad, C. Yin, and M. Debbah, ', '09 June 2017', 16961622, '10.1109/TWC.2017.2683482', 120, 'IEEE', 'https://ieeexplore.ieee.org/abstract/document/7880663']
# idx  78   ['Self-organizing networks: A packet scheduling approach for cover-age/capacity optimization in 4G networks using reinforcement learning', 'M. I. Tiwana, S. J. Nawaz, A. A. Ikram, and M. I. Tiwana,', '', 0, '', 0, '', '']
# idx  79   ['Multi-agent deep reinforcement learningfor dynamic power allocation in wireless networks', 'Y. S. Nasir and D. Guo. (2018). ', '', 0, '', 0, '', '']
# idx  80   ['Joint transmit/receive antenna selection for MIMO systems:A real-valued genetic approach', 'J.-K. Lain, ', '13 January 2011', 11746850, '10.1109/LCOMM.2010.120610.101741', 17, 'IEEE', 'https://ieeexplore.ieee.org/iel5/4234/5685628/05665741.pdf']
# idx  81   ['Selecting array con-figurations for MIMO systems: An evolutionary computation approach', 'P. D. Karamalis, N. D. Skentos, and A. G. Kanatas, ', '03 January 2005', 8258804, '10.1109/TWC.2004.837447', 30, 'IEEE', 'http://ieeexplore.ieee.org/document/1374907/']
# idx  82   ['Power control of cellularradio systems via robust Smith prediction filter', 'B.-K. Lee, H.-W. Chen, and B.-S. Chen, ', '18 October 2004', 8155807, '10.1109/TWC.2004.834705', 39, 'IEEE', 'http://ieeexplore.ieee.org/abstract/document/1343917/']
# idx  83   ['Joint receive antenna selection and symboldetection for MIMO systems: A heterogeneous genetic approach', 'H. Y. Lu and W. H. Fang, ', '13 February 2009', 10475211, '10.1109/LCOMM.2009.081036', 7, 'IEEE', 'http://ieeexplore.ieee.org/document/4783770']
# idx  84   ['GAbased estimation of sparse MIMO channels with superimposed training', 'B. Mansoor, S. J. Nawaz, M. I. Tiwana, J. Ahmed, and A. Haseeb, ', '', 0, '', 0, '', '']
# idx  85   ['Evolutionary algorithms for wireless communications—A review of the state-of-the art', 'S. K. Goudos, ', '', 0, '', 0, '', '']
# idx  86   ['GA based sensing of sparse multipath channels withsuperimposed training sequence', 'S. J. Nawaz, M. I. Tiwana, M. N. Patwary, N. M. Khan, M. I. Tiwana,and A. Haseeb, ', '', 0, '', 0, '', '']
# idx  87   ['Cognitive radioswith genetic algorithms: Intelligent control of software defined radios', 'T. W. Rondeau, B. Le, C. J. Rieser, and C. W. Bostian, ', '', 0, '', 0, '', '']
# idx  88   ['Predicting wireless channel features using neural networks', 'S. Navabi, C. Wang, O. Y. Bursalioglu, and H. Papadopoulos. (2018).', '', 0, '', 0, '', '']
# idx  89   ['A com-prehensive survey of recent advancements in molecular communication', 'N. Farsad, H. B. Yilmaz, A. Eckford, C. B. Chae, and W. Guo, ', '23 May 2017', 16250093, '10.1109/COMST.2016.2527741', 504, 'IEEE', 'https://ieeexplore.ieee.org/document/7405285']
# idx  90   ['Receiver design in molecular communica-tions: An approach based on artificial neural networks', 'X. Qian and M. Di Renzo, ', '', 0, '', 0, '', '']
# idx  91   ['WLAN–based indoor localization using neuralnetworks', 'F. Saleem and S. Wyne, ', '', 0, '', 0, '', '']
# idx  92   ['A deep learning framework for optimization of MISO downlinkbeamforming', 'W. Xia, G. Zheng, Y. Zhu, J. Zhang, J. Wang, and A. P. Petropulu.(2019). ', '', 0, '', 0, '', '']
# idx  93   ['Deep learning in physicallayer communications', 'Z. Qin, H. Ye, G. Y. Li, and B.-H. F. Juang, ', '26 April 2019', 18621104, '10.1109/MWC.2019.1800601', 222, 'IEEE', 'https://ieeexplore.ieee.org/abstract/document/8663966']
# idx  94   ['Learning radio resource management in RANs: Framework,opportunities, and challenges', 'F. D. Calabrese, L. Wang, E. Ghadimi, G. Peters, L. Hanzo, andP. Soldati, ', '17 September 2018', 18094842, '10.1109/MCOM.2018.1701031', 67, 'IEEE', 'https://ieeexplore.ieee.org/document/8466370']
# idx  95   ['User associationand load balancing for massive MIMO through deep learning', 'A. Zappone, L. Sanguinetti, and M. Debbah. (2018). ', '', 0, '', 0, '', '']
# idx  96   ['Applications of deep reinforcement learn-ing in communications and networking: A survey', 'N. C. Luong et al. (2018). ', '', 0, '', 0, '', '']
# idx  97   ['A novel PAPR reduction scheme forOFDM system based on deep learning', 'M. Kim, W. Lee, and D.-H. Cho, ', '08 March 2018', 17614405, '10.1109/LCOMM.2017.2787646', 108, 'IEEE', 'https://ieeexplore.ieee.org/document/8240644']
# idx  98   ['Learning to detect', 'N. Samuel, T. Diskin, and A. Wiesel. (2018). ', '', 0, '', 0, '', '']
# idx  99   ['Deepconvolutional neural networks for massive MIMO fingerprint-based posi-tioning', 'J. Vieira, E. Leitinger, M. Sarajlic, X. Li, and F. Tufvesson, ', '', 0, '', 0, '', '']
# idx  100   ['Deep learningfor wireless physical layer: Opportunities and challenges', 'T. Wang, C.-K. Wen, H. Wang, F. Gao, T. Jiang, and S. Jin, ', '', 0, '', 0, '', '']
# idx  101   ['Learn-ing to optimize: Training deep neural networks for wireless resourcemanagement', 'H. Sun, X. Chen, Q. Shi, M. Hong, X. Fu, and N. D. Sidiropoulos, ', '21 December 2017', 17451560, '10.1109/SPAWC.2017.8227766', 150, 'IEEE', 'https://ieeexplore.ieee.org/document/8227766']
# idx  102   ['Online energy-efficient powercontrol in wireless networks by deep neural networks', 'A. Zappone, M. Debbah, and Z. Altman, ', '27 August 2018', 18054053, '10.1109/SPAWC.2018.8445857', 21, 'IEEE', 'https://ieeexplore.ieee.org/document/8445857']
# idx  103   ['A survey on transfer learning', 'S. J. Pan and Q. Yang, ', '19 August 2010', 11476836, '10.1109/TKDE.2009.191', 9355, 'IEEE', 'https://ieeexplore.ieee.org/document/5288526']
# idx  104   ['A survey ondeep transfer learning', 'C. Tan, F. Sun, T. Kong, W. Zhang, C. Yang, and C. Liu, ', '', 0, '', 0, '', '']
# idx  105   ['Deep unfolding:Model-based inspiration of novel deep architectures', 'J. R. Hershey, J. Le Roux, and F. Weninger. (2014). ', '', 0, '', 0, '', '']
# idx  106   ['Deep learning detection net-works in MIMO decode-forward relay channels', 'X. Jin and H.-N. Kim. (2018). ', '', 0, '', 0, '', '']
# idx  107   ['NeXtgeneration/dynamic spectrum access/cognitive radio wireless networks:A survey', 'I. F. Akyildiz, W.-Y. Lee, M. C. Vuran, and S. Mohanty, ', '', 0, '', 0, '', '']
# idx  108   ['Cognitive radio techniques under practical imperfections:A survey', 'S. K. Sharma, T. E. Bogale, S. Chatzinotas, B. Ottersten, L. B. Le, andX. Wang, ', '23 May 2017', 15602554, '10.1109/COMST.2015.2452414', 153, 'IEEE', 'https://ieeexplore.ieee.org/document/7147789']
# idx  109   ['Machine learn-ing techniques for cooperative spectrum sensing in cognitive radio net-works', 'K. Thilina, K. W. Choi, N. Saquib, and E. Hossain, ', '17 October 2013', 13843215, '10.1109/JSAC.2013.131120', 248, 'IEEE', 'https://ieeexplore.ieee.org/document/6635250']
# idx  110   ['Intelligentpower control for spectrum sharing in cognitive radios: A deep rein-forcement learning approach', 'X. Li, J. Fang, W. Cheng, H. Duan, Z. Chen, and H. Li, ', '24 May 2018', 17773748, '10.1109/ACCESS.2018.2831240', 80, 'IEEE', 'https://ieeexplore.ieee.org/document/8352517']
# idx  111   ['Spectrum sharingoptimization in cellular networks under target performance and budgetrestriction', 'M. Asaduzzaman, R. Abozariba, and M. N. Patwary, ', '16 November 2017', 17375755, '10.1109/VTCSpring.2017.8108226', 2, 'IEEE', 'https://ieeexplore.ieee.org/document/8108226']
# idx  112   ['Machine learning for cognitive net-works: Technology assessment and research challenges', 'T. G. Dietterich and P. Langley, ', '', 0, '', 0, '', '']
# idx  113   ['A survey of self-organizing networks', 'A. Kumar, ', '', 0, '', 0, '', '']
# idx  114   ['A survey on machine-learningtechniques in cognitive radios', 'M. Bkassiny, Y. Li, and S. K. Jayaweera, ', '31 July 2013', 13685876, '10.1109/SURV.2012.100412.00017', 323, 'IEEE', 'https://ieeexplore.ieee.org/document/6336689']
# idx  115   ['Machine learning for cognitive network management', 'S. Ayoubi et al., ', '12 January 2018', 17489648, '10.1109/MCOM.2018.1700560', 102, 'IEEE', 'http://ieeexplore.ieee.org/document/8255757/']
# idx  117   ['Quantum computation and quantuminformation', 'M. A. Nielsen and I. L. Chuang, ', '', 0, '', 0, '', '']
# idx  118   ['Quantum communications: Explained for communication engi-neers', 'S. Imre, ', '16 August 2013', 13694985, '10.1109/MCOM.2013.6576335', 24, 'IEEE', 'http://ieeexplore.ieee.org/abstract/document/6576335/']
# idx  119   ['Quantum communications', 'J. D. Franson, ', '', 0, '', 0, '', '']
# idx  120   ['Quantum communications: An engineering approach', 'A. N. Pinto, N. A. Silva, N. J. Muga, A. J. Almeida, and D. F. Pereira,', '', 0, '', 0, '', '']
# idx  121   ['A survey on quantum channelcapacities', 'L. Gyongyosi, S. Imre, and H. V. Nguyen, ', '06 May 2019', 17829227, '10.1109/COMST.2017.2786748', 116, 'IEEE', 'https://ieeexplore.ieee.org/document/8242350']
# idx  122   ['A single quantum cannot be cloned', 'W. K. Wootters and W. H. Zurek, ', '', 0, '', 0, '', '']
# idx  123   ['Entanglement-assisted capacity of a quantum channel and the reverseShannon theorem', 'C. H. Bennett, P. W. Shor, J. A. Smolin, and A. V. Thapliyal,', '07 November 2002', 7407456, '10.1109/TIT.2002.802612', 367, 'IEEE', 'https://ieeexplore.ieee.org/iel5/18/22215/01035117.pdf']
# idx  124   ['The private classical capacity and quantum capacity of aquantum channel', 'I. Devetak, ', '10 January 2005', 8267891, '10.1109/TIT.2004.839515', 479, 'IEEE', 'https://ieeexplore.ieee.org/iel5/18/30067/01377491.pdf']
# idx  125   ['Identifying the informationgain of a quantum measurement', 'M. Berta, J. M. Renes, and M. M. Wilde, ', '11 August 2014', 14515021, '10.1109/ISIT.2014.6874849', 1, 'IEEE', 'http://ieeexplore.ieee.org/document/6874849/']
# idx  126   ['Analysis of quantum key distribution basedsatellite communication', 'V. Sharma and S. Banerjee, ', '', 0, '', 0, '', '']
# idx  127   ['Quantum key distribution technologies', 'K. Inoue, ', '', 0, '', 0, 'IEEE', '']
# idx  128   ['Teleporting an unknown quantum state via dual clas-sical and einstein-podolsky-rosen channels', 'C. H. Bennett, G. Brassard, C. Crépeau, R. Jozsa, A. Peres, andW. K. Wootters, ', '', 0, '', 0, '', '']
# idx  129   ['Communication via one- and two-particle operators on Einstein-Podolsky-Rosen states', 'C. H. Bennett and S. J. Wiesner, ', '', 0, '', 0, '', '']
# idx  130   ['Quantum spread spec-trum multiple access', 'J. C. Garcia-Escartin and P. Chamorro-Posada, ', '21 November 2014', 14753628, '10.1109/JSTQE.2014.2360366', 6, 'IEEE', 'https://ieeexplore.ieee.org/document/6910207/']
# idx  131   ['The quantum theory of optical communications', 'J. H. Shapiro, ', '04 December 2009', 11004961, '10.1109/JSTQE.2009.2024959', 96, 'IEEE', 'https://ieeexplore.ieee.org/iel5/2944/4481213/05223603.pdf']
# idx  132   ['Feasibility ofquantum communications in aquatic scenario', 'S. Tarantino, D. Cozzolino, K. Rottwitt, and D. Bacco, ', '08 November 2018', 18249047, '10.1109/IPCon.2018.8527325', 3, 'IEEE', 'https://ieeexplore.ieee.org/document/8527325']
# idx  133   ['Terahertz essential devices technique research based on quantumcommunication', 'J. Du, ', '17 December 2018', 18362707, '10.1109/IAEAC.2018.8577895', 1, 'IEEE', 'http://ieeexplore.ieee.org/document/8577895']
# idx  134   ['Quantum communication forwireless wide-area networks', 'S.-T. Cheng, C.-Y. Wang, and M.-H. Tao, ', '05 July 2005', 8513938, '10.1109/JSAC.2005.851157', 72, 'IEEE', 'https://ieeexplore.ieee.org/document/1461505']
# idx  135   ['Evidence for quantum annealing with more than onehundred qubits', 'S. Boixo et al., ', '', 0, '', 0, '', '']
# idx  136   ['The capacity of the quantum channel with general signalstates', 'A. S. Holevo, ', '06 August 2002', 5812019, '10.1109/18.651037', 717, 'IEEE', 'https://ieeexplore.ieee.org/document/651037']
# idx  137   ['Capacity of the noisy quantum channel', 'S. Lloyd, ', '', 0, '', 0, '', '']
# idx  138   ['The capacity of a quantum channel for simul-taneous transmission of classical and quantum information', 'I. Devetak and P. W. Shor, ', '', 0, '', 0, '', '']
# idx  139   ['Entanglement-assisted communicationof classical and quantum information', 'M.-H. Hsieh and M. M. Wilde, ', '16 August 2010', 11473339, '10.1109/TIT.2010.2053903', 63, 'IEEE', 'https://ieeexplore.ieee.org/iel5/18/5550275/05550293.pdf']
# idx  140   ['Trading classical communication, quan-tum communication, and entanglement in quantum Shannon theory', 'M.-H. Hsieh and M. M. Wilde, ', '', 0, '', 0, 'IEEE', '']
# idx  141   ['Entanglement-assistedquantum turbo codes', 'M. M. Wilde, M.-H. Hsieh, and Z. Babar, ', '', 0, '', 0, 'IEEE', '']
# idx  142   ['The squashed entangle-ment of a quantum channel', 'M. Takeoka, S. Guha, and M. M. Wilde, ', '10 July 2014', 14432022, '10.1109/TIT.2014.2330313', 59, 'IEEE', 'https://ieeexplore.ieee.org/iel7/18/4667673/06832533.pdf']
# idx  143   ['Consequences ofmany-cell correlations in clocked quantum-dot cellular automata', 'M. Taucer, F. Karim, K. Walus, and R. A. Wolkow, ', '07 July 2015', 15289764, '10.1109/TNANO.2015.2426058', 11, 'IEEE', 'https://ieeexplore.ieee.org/document/7098406']
# idx  144   ['A device architecture for computing withquantum dots', 'C. S. Lent and P. D. Tougaw, ', '06 August 2002', 5594749, '10.1109/5.573740', 856, 'IEEE', 'https://ieeexplore.ieee.org/document/573740']
# idx  145   ['Quantum-dot cellularautomata: Theory and application', 'F. Qadir, P. Z. Ahmad, S. J. Wani, and M. A. Peer, ', '', 0, '', 0, '', '']
# idx  146   ['Automateddesign architecture for 1-D cellular automata using quantum cellularautomata', 'V. A. Mardiris, G. C. Sirakoulis, and I. G. Karafyllidis, ', '05 August 2015', 15346061, '10.1109/TC.2014.2366745', 11, 'IEEE', 'http://ieeexplore.ieee.org/abstract/document/6945867/']
# idx  147   ['Design of generalized pipeline cellulararray in quantum-dot cellular automata', 'A. F. Almatrood and H. Singh, ', '14 March 2018', 17633584, '10.1109/LCA.2017.2719021', 5, 'IEEE', 'http://ieeexplore.ieee.org/abstract/document/7956156/']
# idx  148   ['A signal distribution networkfor sequential quantum-dot cellular automata systems', 'H. Hast, S. Khorbotly, and D. Tougaw, ', '07 July 2015', 15289776, '10.1109/TNANO.2015.2428651', 7, 'IEEE', 'https://ieeexplore.ieee.org/document/7098419?arnumber=7098419']
# idx  149   ['A survey of quantum-like approachesto decision making and cognition', 'M. Ashtiani and M. A. Azgomi, ', '', 0, '', 0, '', '']
# idx  150   ['Quantitative predictions in quantumdecision theory', 'V. I. Yukalov and D. Sornette, ', '', 0, '', 0, 'IEEE', '']
# idx  152   ['Long-distance trust-free quantum keydistribution', 'N. L. Piparo and M. Razavi, ', '', 0, '', 0, 'IEEE', '']
# idx  153   ['Scheme of thinking quantum systems', 'V. I. Yukalov and D. Sornette, ', '', 0, '', 0, '', '']
# idx  154   ['An introductory review on quantumgame theory', 'W. Liu, J. liu, M. Cui, and M. He, ', '', 0, '', 0, '', '']
# idx  155   ['Qubit devices and the issue of quantum decoherence', 'H. E. Brandt, ', '', 0, '', 0, '', '']
# idx  156   ['Exploiting randomness in quantum infor-mation processing', 'C. F. Lee and N. F. Johnson, ', '', 0, '', 0, '', '']
# idx  157   ['A survey of the current status of research onquantum games', 'D. Huang and S. Li, ', '', 0, '', 0, '', '']
# idx  158   ['Variations on classical andquantum extractors', 'M. Berta, O. Fawzi, V. Scholz, and O. Szehr, ', '', 0, '', 0, 'IEEE', '']
# idx  159   ['The bounded-storage model in thepresence of a quantum adversary', 'R. T. Konig and B. M. Terhal, ', '', 0, '', 0, 'IEEE', 'https://authors.library.caltech.edu/9660/1/KOEieeetit08.pdf']
# idx  160   ['Quantum-proof randomnessextractors via operator space theory', 'M. Berta, O. Fawzi, and V. B. Scholz, ', '', 0, '', 0, 'IEEE', '']
# idx  161   ['Extracting randomness viarepeated condensing', 'R. S. O. Reingold and A. Wigderson, ', '', 0, '', 0, '', '']
# idx  162   ['Quantum search algorithms,quantum wireless, and a low-complexity maximum likelihood iterativequantum multi-user detector design', 'P. Botsinis, S. X. Ng, and L. Hanzo, ', '10 May 2013', 13730378, '10.1109/ACCESS.2013.2259536', 44, 'IEEE', 'https://ieeexplore.ieee.org/document/6515077']
# idx  163   ['Low-complexity soft-output quantum-assisted multiuser detection for direct-sequence spread-ing and slow subcarrier-hopping aided SDMA-OFDM systems', 'P. Botsinis, D. Alanis, S. X. Ng, and L. Hanzo, ', '23 May 2017', 14316372, '10.1109/ACCESS.2014.2322013', 23, 'IEEE', 'https://ieeexplore.ieee.org/document/6812127']
# idx  164   ['Fixed-complexity quantum-assistedmulti-user detection for CDMA and SDMA', 'P. Botsinis, S. X. Ng, and L. Hanzo, ', '25 March 2014', 0, '10.1109/TCOMM.2014.012514.130615', 32, 'IEEE', 'http://ieeexplore.ieee.org/document/6730885/']
# idx  165   ['Iterativequantum-assisted multi-user detection for multi-carrier interleave divi-sion multiple access systems', 'P. Botsinis, D. Alanis, Z. Babar, S. X. Ng, and L. Hanzo, ', '15 October 2015', 15524641, '10.1109/TCOMM.2015.2458857', 28, 'IEEE', 'http://ieeexplore.ieee.org/abstract/document/7163557/']
# idx  166   ['Quan-tum search-aided multi-user detection of IDMA-assisted multi-layeredvideo streaming', 'P. Botsinis, Y. Huo, D. Alanis, Z. Babar, S. X. Ng, and L. Hanzo, ', '06 May 2019', 17381088, '10.1109/ACCESS.2017.2732358', 7, 'IEEE', 'http://ieeexplore.ieee.org/abstract/document/7993006/']
# idx  167   ['The impact of nodeselfishness on multicasting in delay tolerant networks', 'Y. Li, G. Su, D. O. Wu, D. Jin, L. Su, and L. Zeng, ', '13 June 2011', 12060236, '10.1109/TVT.2011.2149552', 114, 'IEEE', 'http://ieeexplore.ieee.org/document/5762399/']
# idx  168   ['Quantum-assistedrouting optimization for self-organizing networks', 'D. Alanis, P. Botsinis, S. X. Ng, and L. Hanzo, ', '23 May 2017', 14429399, '10.1109/ACCESS.2014.2327596', 30, 'IEEE', 'https://ieeexplore.ieee.org/document/6825798']
# idx  169   ['Joint channel estimation anddata detection in MIMO-OFDM systems: A sparse Bayesian learningapproach', 'R. Prasad, C. R. Murthy, and B. D. Rao, ', '10 September 2015', 15432970, '10.1109/TSP.2015.2451071', 74, 'IEEE', 'https://ieeexplore.ieee.org/document/7140825']
# idx  170   ['Joint channel estima-tion and multiuser detection for SDMA/OFDM based on dual repeatedweighted boosting search', 'J. Zhang, S. Chen, X. Mu, and L. Hanzo, ', '12 September 2011', 12219122, '10.1109/TVT.2011.2161356', 30, 'IEEE', 'https://ieeexplore.ieee.org/document/5941035']
# idx  172   ['Quantum computing and super-vised machine learning: Training, model selection, and error estima-tion', 'L. Oneto, S. Ridella, and D. Anguita, ', '', 0, '', 0, '', '']
# idx  173   ['Quantum speed-up for unsuper-vised learning', 'E. Aïmeur, G. Brassard, and S. Gambs, ', '', 0, '', 0, '', '']
# idx  174   ['Quantum reinforce-ment learning', 'D. Dong, C. Chen, H. Li, and T. J. Tarn, ', '', 0, '', 0, 'IEEE', '']
# idx  175   ['Advances in quantumreinforcement learning', 'V. Dunjko, J. M. Taylor, and H. J. Briegel, ', '', 0, '', 0, 'IEEE', '']
# idx  176   ['A quantum inspired reinforce-ment learning technique for beyond next generation wireless networks', 'S. Nuuman, D. Grace, and T. Clarke, ', '18 June 2015', 15220492, '10.1109/WCNCW.2015.7122566', 1, 'IEEE', 'https://ieeexplore.ieee.org/document/7122566']
# idx  177   ['Towards quantum machine learning with tensor networks', 'W. Huggins, P. Patel, K. B. Whaley, and E. M. Stoudenmire. (2018).', '', 0, '', 0, '', '']
# idx  178   ['A quantum machine learn-ing algorithm based on generative models', 'X. Gao, Z.-Y. Zhang, and L.-M. Duan, ', '', 0, '', 0, '', '']
# idx  179   ['An algorithm of quantum restrictedboltzmann machine network based on quantum gates and its application', 'P. Zhang, S. Li, and Y. Zhou, ', '', 0, '', 0, '', '']
# idx  180   ['Quantumdeep learning neural networks', 'A. Kamruzzaman, Y. Alhwaiti, A. Leider, and C. C. Tappert ', '', 0, '', 0, '', '']
# idx  181   ['Quantum neural networks(QNNs): Inherently fuzzy feedforward neural networks', 'G. Purushothaman and N. B. Karayiannis, ', '06 August 2002', 5594482, '10.1109/72.572106', 121, 'IEEE', 'https://ieeexplore.ieee.org/document/572106']
# idx  182   ['Quantum neural network', 'M. V. Altaisky. (2001). ', '', 0, '', 0, '', '']
# idx  183   ['Quantum neural networks', 'A. A. Ezhov and D. Ventura, ', '', 0, '', 0, '', '']
# idx  184   ['Quantum perceptron models', 'A. Kapoor, N. Wiebe, and K. M. Svore, ', '', 0, '', 0, '', '']
# idx  185   ['Quantum support vectormachine for big data classification', 'P. Rebentrost, M. Mohseni, and S. Lloyd, ', '', 0, '', 0, '', '']
# idx  186   ['Quantum sparse support vectormachines', 'T. Arodz and S. Saeedi. (2019). ', '', 0, '', 0, '', '']
# idx  187   ['Sparse representationfor wireless communications: A compressive sensing approach', 'Z. Qin, J. Fan, Y. Liu, Y. Gao, and G. Y. Li, ', '26 April 2018', 17750705, '10.1109/MSP.2018.2789521', 104, 'IEEE', 'https://ieeexplore.ieee.org/abstract/document/8350399/']
# idx  188   ['Application of quantumannealing to training of deep neural networks', 'S. H. Adachi and M. P. Henderson. (2015). ', '', 0, '', 0, '', '']
# idx  189   ['Quantum deep learn-ing', 'N. Wiebe, A. Kapoor, and K. M. Svore. (2014). ', '', 0, '', 0, '', '']
# idx  190   ['Distributed secure quantum machine learn-ing', 'Y.-B. Sheng and L. Zhou, ', '', 0, '', 0, '', '']
# idx  191   ['A survey towards an integration of big data ana-lytics to big insights for value-creation', 'M. K. Saggi and S. Jain, ', '', 0, '', 0, '', '']
# idx  192   ['Quantum gate learning in qubitnetworks: Toffoli gate without time-dependent control', 'L. Banchi, N. Pancotti, and S. Bose, ', '', 0, '', 0, '', '']
# idx  193   ['Quantum computing in the NISQ era and beyond', 'J. Preskill, ', '', 0, '', 0, '', '']
# idx  194   ['Future directions of quantum informationprocessing: A workshop on the emerging science and technology ofquantum computation, communication, and measurement', 'K. Klemic and J. Zeigler, Eds., ', '', 0, '', 0, '', '']
# idx  195   ['Google moves toward quantum supremacy with 72-qubitcomputer', 'E. Connover, ', '', 0, '', 0, '', '']
# idx  196   ['A space-efficient quantum computer simulator suitable for high-speed FPGAimplementation', 'M. P. Frank, L. Oniciuc, U. H. Meyer-Baese, and I. Chiorescu, ', '', 0, '', 0, '', '']
# idx  197   ['A grid enabled quantum com-puter simulator', 'S. Caraiman, A. Archip, and V. Manta, ', '', 0, '', 0, '', '']
# idx  198   ['Competitive cachingwith machine learned advice', 'T. Lykouris and S. Vassilvitskii. (2018). ', '', 0, '', 0, '', '']
# idx  199   ['A deep reinforcementlearning-based framework for content caching', 'C. Zhong, M. C. Gursoy, and S. Velipasalar, ', '', 0, '', 0, '', '']
# idx  200   ['Learn to cache:Machine learning for network edge caching in the big data era', 'Z. Chang, L. Lei, Z. Zhou, S. Mao, and T. Ristaniemi, ', '04 July 2018', 17895127, '10.1109/MWC.2018.1700317', 106, 'IEEE', 'https://ieeexplore.ieee.org/document/8403948']
# idx  201   ['A quantumapproximate optimization algorithm', 'E. Farhi, J. Goldstone, and S. Gutmann. (2014). ', '', 0, '', 0, '', '']
# idx  202   ['Multi-objective routingoptimization using evolutionary algorithms', 'H. Yetgin, K. T. K. Cheung, and L. Hanzo, ', '11 June 2012', 12805181, '10.1109/WCNC.2012.6214324', 28, 'IEEE', 'http://ieeexplore.ieee.org/document/6214324/']
# idx  203   ['Multi-task learning as multi-objective optimiza-tion', 'O. Sener and V. Koltun, ', '', 0, '', 0, '', '']
# idx  204   ['Quantum computing in big data analytics:A survey', 'T. A. Shaikh and R. Ali, ', '13 March 2017', 16726160, '10.1109/CIT.2016.79', 15, 'IEEE', 'https://ieeexplore.ieee.org/document/7876324']
# idx  205   ['Emerging trends ofgreen IoT for smart world', 'A. Gapchup, A. Wani, A. Wadghule, and S. Jadhav, ', '', 0, '', 0, '', '']
# idx  206   ['Goinggreen with IoT for smart world-an overview', 'N. S. Sehnaz, L. Hemalatha, M. C. S. Geetha, and I. E. Shanthi, ', '', 0, '', 0, '', '']
# idx  207   ['A survey on network methodologies for real-time analytics of massiveIoT data and open research issues', 'S. Verma, Y. Kawamoto, Z. M. Fadlullah, H. Nishiyama, and N. Kato,', '21 August 2017', 17136510, '10.1109/COMST.2017.2694469', 226, 'IEEE', 'https://ieeexplore.ieee.org/document/7900337']
# idx  208   ['Towardsthe science of security and privacy in machine learning', 'N. Papernot, P. McDaniel, A. Sinha, and M. Wellman. (2016). ', '', 0, '', 0, '', '']
# idx  209   ['Machine learning based antennadesign for physical layer security in ambient backscatter communi-cations', 'T. Hong, C. Liu, and M. Kadoch, ', '', 0, '', 0, '', '']
# idx  210   ['Training-based antenna selection for PER minimization: A POMDPapproach', 'S. Padmanabhan, R. G. Stephen, C. R. Murthy, and M. Coupechoux,', '03 September 2015', 15432794, '10.1109/TCOMM.2015.2455504', 12, 'IEEE', 'http://ieeexplore.ieee.org/document/7155517']
# idx  211   ['Learning and data-driven beam selectionfor mmWave communications: An angle of arrival-based approach', 'C. Antón-Haro and X. Mestre, ', '21 February 2019', 18468050, '10.1109/ACCESS.2019.2895594', 30, 'IEEE', 'https://ieeexplore.ieee.org/document/8630933']
# idx  212   ['Learning state selection for reconfig-urable antennas: A multi-armed bandit approach', 'N. Gulati and K. R. Dandekar, ', '27 February 2014', 14131500, '10.1109/TAP.2013.2276414', 44, 'IEEE', 'https://ieeexplore.ieee.org/document/6574205']
# idx  213   ['Accelerating beamsweeping in mmWave standalone 5G new radios using recurrent neuralnetworks', 'A. Mazin, M. Elkourdi, and R. D. Gitlin. (2018). ', '', 0, '', 0, '', '']
# idx  214   ['Machine learning algorithm forwireless indoor localization', 'O. A. Abdullah and I. Abdel-Qader, ', '', 0, '', 0, '', '']
# idx  215   ['Indoor localization usingvisible light via fusion of multiple classifiers', 'X. Guo, S. Shao, N. Ansari, and A. Khreishah, ', '14 November 2017', 0, '10.1109/JPHOT.2017.2767576', 58, 'IEEE', 'https://ieeexplore.ieee.org/document/8089342']
# idx  216   ['Terabit free-space data transmission employing orbitalangular momentum multiplexing', 'J. Wang et al., ', '', 0, '', 0, '', '']
# idx  217   ['Adaptive demodulator using machinelearning for orbital angular momentum shift keying', 'J. Li, M. Zhang, and D. Wang, ', '31 July 2017', 17132608, '10.1109/LPT.2017.2726139', 37, 'IEEE', 'http://ieeexplore.ieee.org/document/7976374']
# idx  218   ['Analysis of an adaptive orbital angular momentumshift keying decoder based on machine learning under oceanic turbulencechannels', 'X.-Z. Cui et al., ', '', 0, '', 0, '', '']
# idx  219   ['Ubiquitous cell-free massive MIMOcommunications', 'G. Interdonato, E. Björnson, H. Q. Ngo, P. Frenger, andE. G. Larsson. (2018). ', '', 0, '', 0, '', '']
# idx  220   ['OFDM-Autoencoder for end-to-end learning of communications sys-tems', 'A. Felix, S. Cammerer, S. Dörner, J. Hoydis, and S. ten Brink. (2018).', '', 0, '', 0, '', '']
# idx  221   ['Learning to communicate:Channel auto-encoders, domain specific regularizers, and attention', 'T. J. O’Shea, K. Karra, and T. C. Clancy, ', '27 March 2017', 16774449, '10.1109/ISSPIT.2016.7886039', 119, 'IEEE', 'https://ieeexplore.ieee.org/document/7886039']
# idx  222   ['Deep learn-ing based MIMO communications', 'T. J. O’Shea, T. Erpek, and T. C. Clancy. (2017). ', '', 0, '', 0, '', '']
# idx  223   ['Deep learningbased communication over the air', 'S. Dörner, S. Cammerer, J. Hoydis, and S. ten Brink, ', '19 February 2018', 17581583, '10.1109/JSTSP.2017.2784180', 349, 'IEEE', 'https://ieeexplore.ieee.org/document/8214233']
# idx  224   ['End-to-end learning of com-munications systems without a channel model', 'F. A. Aoudia and J. Hoydis. (2018). ', '', 0, '', 0, '', '']
# idx  225   ['Dictionary learning-based sparse channel repre-sentation and estimation for FDD massive MIMO systems', 'Y. Ding and B. D. Rao, ', '10 August 2018', 18007396, '10.1109/TWC.2018.2843786', 59, 'IEEE', 'https://ieeexplore.ieee.org/document/8383706']
# idx  227   ['On the performance of non-orthogonal multiple access in 5G systems with randomly deployed users', 'Z. Ding, Z. Yang, P. Fan, and H. V. Poor, ', '01 August 2014', 14500738, '10.1109/LSP.2014.2343971', 1326, 'IEEE', 'http://ieeexplore.ieee.org/document/6868214/']
# idx  228   ['Embracingnon-orthogonalmultiple access in future wireless networks', 'Z.-G. Ding, M. Xu, Y. Chen, M.-G. Peng, and H. V. Poor, ', '', 0, '', 0, '', '']
# idx  229   ['NOMA based resource allocation and mobility enhancement frameworkfor IoT in next generation cellular networks', 'R. Abozariba, M. K. Naeem, M. Patwary, M. Seyedebrahimi, and P. Bull,', '19 March 2019', 18526678, '10.1109/ACCESS.2019.2896008', 18, 'IEEE', 'https://ieeexplore.ieee.org/document/8629874']
# idx  230   ['Detec-tion for 5G-NOMA: An online adaptive machine learning approach', 'D. A. Awan, R. L. G. Cavalcante, M. Yukawa, and S. Stanczak, ', '31 July 2018', 17971370, '10.1109/ICC.2018.8422449', 21, 'IEEE', 'https://ieeexplore.ieee.org/iel7/8411665/8422068/08422449.pdf']
# idx  231   ['The application of machine learningin mmWave-NOMA systems', 'J. Cui, Z. Ding, and P. Fan, ', '', 0, '', 0, '', '']
# idx  232   ['Deep learning for an effec-tive nonorthogonal multiple access scheme', 'G. Gui, H. Huang, Y. Song, and H. Sari, ', '17 September 2018', 18095115, '10.1109/TVT.2018.2848294', 321, 'IEEE', 'https://ieeexplore.ieee.org/document/8387468']
# idx  233   ['On the performanceand optimization for MEC networks using uplink NOMA', 'Y. Ye, G. Lu, R. Q. Hu, and L. Shi. (2019). ', '', 0, '', 0, '', '']
# idx  234   ['Delay minimizationfor NOMA-MEC offloading', 'Z. Ding, D. W. K. Ng, R. Schober, and H. V. Poor, ', '09 November 2018', 18210767, '10.1109/LSP.2018.2876019', 97, 'IEEE', 'http://ieeexplore.ieee.org/document/8492422/']
# idx  235   ['Applications ofmachine learning to cognitive radio networks', 'C. Clancy, J. Hecker, E. Stuntebeck, and T. O’Shea, ', '10 September 2007', 9624485, '10.1109/MWC.2007.4300983', 206, 'IEEE', 'http://ieeexplore.ieee.org/document/4300983']
# idx  236   ['Role of artificial intelligence in cog-nitive radio networks', 'S. Singhal, S. Gupta, and A. Sinha, ', '', 0, '', 0, '', '']

# %%
# pd.set_option('display.max_rows', 300)
q1.csv_data.head(300)
# Out:
#                                                  title  \
# 0    Quantum Machine Learning for 6G Communication ...
# 2    A survey of 5G network: Architecture andemergi...
# 3    Towards massive connectivity support for scal-...
# 4    Towards massive machinetype communications in ...
# 5                            Open issues and beyond 5G
# 6    6G vision and requirements: Is there any needf...
# 7                            A speculative study on 6G
# 8                                6G: The next frontier
# 9    A vision of 6Gwireless systems: Applications, ...
# 11   Thirty years of machine learning: The road to ...
# 12   Big data analytics, machine learning, and arti...
# 13   When machine learningmeets big data: A wireles...
# 14   Collaborative distributed Q-learning forRACH c...
# 15   A very brief introduction to machine learning ...
# 16   Deep learning inmobile and wireless networking...
# 17   Wireless networksdesign in the era of deep lea...
# 18   Channelagnostic end-to-end learning based comm...
# 19   An introduction to deep learning for the physi...
# 20   Power of deep learning for channelestimation a...
# 21   Deep reinforcement learning for resource alloc...
# 22   Propagationchannels for mmWave vehicular commu...
# 23   Deep learning-basedchannel estimation for beam...
# 24   Machine learningfor vehicular networks: Recent...
# 25   Deep learningconvolutional neural networks for...
# 26   On a novel deep-learning-based intelligent par...
# 27   Enabling cognitive smart citiesusing big data ...
# 28   Quantum computing is exciting and important-re...
# 29           A survey on quantum computing technol-ogy
# 30      Quantum algorithms for wireless communications
# 31   The quantum dynamic capacity for-mula of a qua...
# ..                                                 ...
# 206    Goinggreen with IoT for smart world-an overview
# 207  A survey on network methodologies for real-tim...
# 208  Towardsthe science of security and privacy in ...
# 209  Machine learning based antennadesign for physi...
# 210  Training-based antenna selection for PER minim...
# 211  Learning and data-driven beam selectionfor mmW...
# 212  Learning state selection for reconfig-urable a...
# 213  Accelerating beamsweeping in mmWave standalone...
# 214  Machine learning algorithm forwireless indoor ...
# 215  Indoor localization usingvisible light via fus...
# 216  Terabit free-space data transmission employing...
# 217  Adaptive demodulator using machinelearning for...
# 218  Analysis of an adaptive orbital angular moment...
# 219    Ubiquitous cell-free massive MIMOcommunications
# 220  OFDM-Autoencoder for end-to-end learning of co...
# 221  Learning to communicate:Channel auto-encoders,...
# 222           Deep learn-ing based MIMO communications
# 223      Deep learningbased communication over the air
# 224  End-to-end learning of com-munications systems...
# 225  Dictionary learning-based sparse channel repre...
# 227  On the performance of non-orthogonal multiple ...
# 228  Embracingnon-orthogonalmultiple access in futu...
# 229  NOMA based resource allocation and mobility en...
# 230  Detec-tion for 5G-NOMA: An online adaptive mac...
# 231  The application of machine learningin mmWave-N...
# 232  Deep learning for an effec-tive nonorthogonal ...
# 233  On the performanceand optimization for MEC net...
# 234          Delay minimizationfor NOMA-MEC offloading
# 235  Applications ofmachine learning to cognitive r...
# 236  Role of artificial intelligence in cog-nitive ...
#
#                                                 author               date  \
# 0    Syed Junaid Nawaz, Shree Krishna Sharma, Shurj...      04 April 2019
# 2                          A. Gupta and E. R. K. Jha,      07 August 2015
# 3                               C. Bockelmann et al.,        18 June 2018
# 4              S. K. Sharma and X. Wang. (Aug. 2018).
# 5            M. Chiani, E. Paolini, and F. Callegati,
# 6                             K. David and H. Berndt,      30 August 2018
# 7    F. Tariq, M. Khandaker, K.-K. Wong, M. Imran, ...
# 8    E. C. Strinati, S. Barbarossa, J. L. Gonzalez-...
# 9       W. Saad, M. Bennis, and M. Chen. (Mar. 2019).
# 11   J. Wang, C. Jiang, H. Zhang, Y. Ren, K.-C. Che...
# 12   M. G. Kibria, K. Nguyen, G. P. Villardi, O. Zh...       28 June 2018
# 13       Y. Liu, S. Bi, Z. Shi, and L. Hanzo. (2019).
# 14                          S. K. Sharma and X. Wang,         06 May 2019
# 15                                        O. Simeone,    20 December 2018
# 16       C. Zhang, P. Patras, and H. Haddadi. (2018).
# 17    A. Zappone, M. Di Renzo, and M. Debbah. (2019).
# 18   H. Ye, G. Y. Li, B.-H. F. Juang, and K. Sivane...
# 19                           T. O’Shea and J. Hoydis,    19 December 2017
# 20                  H. Ye, G. Y. Li, and B.-H. Juang,    16 February 2018
# 21                                H. Ye and G. Y. Li,        31 July 2018
# 22     F. Jameel, S. Wyne, S. J. Nawaz, and Z. Chang,    13 February 2019
# 23    H. He, C.-K. Wen, S. Jin, and G. Y. Li. (2018).
# 24   H. Ye, L. Liang, G. Y. Li, J. Kim, L. Lu, and ...        21 May 2018
# 25   S. Riyaz, K. Sankhe, S. Ioannidis, and K. Chow...  17 September 2018
# 26     F. Tang, B. Mao, Z. M. Fadlullah, and N. Kato,   17 September 2018
# 27                     M. Mohammadi and A. Al-Fuqaha,    13 February 2018
# 28                                            C. Day,
# 29                          L. Gyongyosi and S. Imre,
# 30                                P. Botsinis et al.,         31 May 2019
# 31                       M. M. Wilde and M.-H. Hsieh,
# ..                                                 ...                ...
# 206  N. S. Sehnaz, L. Hemalatha, M. C. S. Geetha, a...
# 207  S. Verma, Y. Kawamoto, Z. M. Fadlullah, H. Nis...     21 August 2017
# 208  N. Papernot, P. McDaniel, A. Sinha, and M. Wel...
# 209                   T. Hong, C. Liu, and M. Kadoch,
# 210  S. Padmanabhan, R. G. Stephen, C. R. Murthy, a...  03 September 2015
# 211                      C. Antón-Haro and X. Mestre,    21 February 2019
# 212                     N. Gulati and K. R. Dandekar,    27 February 2014
# 213  A. Mazin, M. Elkourdi, and R. D. Gitlin. (2018).
# 214                O. A. Abdullah and I. Abdel-Qader,
# 215     X. Guo, S. Shao, N. Ansari, and A. Khreishah,    14 November 2017
# 216                                   J. Wang et al.,
# 217                     J. Li, M. Zhang, and D. Wang,        31 July 2017
# 218                                 X.-Z. Cui et al.,
# 219  G. Interdonato, E. Björnson, H. Q. Ngo, P. Fre...
# 220  A. Felix, S. Cammerer, S. Dörner, J. Hoydis, a...
# 221         T. J. O’Shea, K. Karra, and T. C. Clancy,       27 March 2017
# 222  T. J. O’Shea, T. Erpek, and T. C. Clancy. (201...
# 223  S. Dörner, S. Cammerer, J. Hoydis, and S. ten ...   19 February 2018
# 224               F. A. Aoudia and J. Hoydis. (2018).
# 225                            Y. Ding and B. D. Rao,      10 August 2018
# 227         Z. Ding, Z. Yang, P. Fan, and H. V. Poor,      01 August 2014
# 228  Z.-G. Ding, M. Xu, Y. Chen, M.-G. Peng, and H....
# 229  R. Abozariba, M. K. Naeem, M. Patwary, M. Seye...      19 March 2019
# 230  D. A. Awan, R. L. G. Cavalcante, M. Yukawa, an...       31 July 2018
# 231                      J. Cui, Z. Ding, and P. Fan,
# 232           G. Gui, H. Huang, Y. Song, and H. Sari,   17 September 2018
# 233       Y. Ye, G. Lu, R. Q. Hu, and L. Shi. (2019).
# 234  Z. Ding, D. W. K. Ng, R. Schober, and H. V. Po...   09 November 2018
# 235  C. Clancy, J. Hecker, E. Stuntebeck, and T. O’...  10 September 2007
# 236               S. Singhal, S. Gupta, and A. Sinha,
#
#        INSPEC                          DOI  citations publisher  \
# 0    18609246  10.1109/ACCESS.2019.2909490        170      IEEE
# 2    15351996  10.1109/ACCESS.2015.2461602       1315      IEEE
# 3    17829625  10.1109/ACCESS.2018.2837382        131      IEEE
# 4           0                                       0
# 5           0                                       0
# 6    18058905     10.1109/MVT.2018.2848498        250      IEEE
# 7           0                                       0
# 8           0                                       0
# 9           0                                       0
# 11          0                                       0
# 12   17905641  10.1109/ACCESS.2018.2837692        184      IEEE
# 13          0                                       0
# 14   18595867   10.1109/LCOMM.2019.2896929         36      IEEE
# 15          0    10.1109/TCCN.2018.2881442        184      IEEE
# 16          0                                       0
# 17          0                                       0
# 18          0                                       0
# 19   17525661    10.1109/TCCN.2017.2758370       1063      IEEE
# 20   17595984     10.1109/LWC.2017.2757490        687      IEEE
# 21   17971374     10.1109/ICC.2018.8422586         86      IEEE
# 22   18469754     10.1109/MWC.2018.1800174         42      IEEE
# 23          0                                       0
# 24   17768300     10.1109/MVT.2018.2811185        149      IEEE
# 25   18094844    10.1109/MCOM.2018.1800153        112      IEEE
# 26   18094850    10.1109/MCOM.2018.1701227         71      IEEE
# 27   17578019    10.1109/MCOM.2018.1700298        153      IEEE
# 28          0                                       0
# 29          0                                       0
# 30   18726267   10.1109/COMST.2018.2882385         34      IEEE
# 31          0                                       0
# ..        ...                          ...        ...       ...
# 206         0                                       0
# 207  17136510   10.1109/COMST.2017.2694469        226      IEEE
# 208         0                                       0
# 209         0                                       0
# 210  15432794   10.1109/TCOMM.2015.2455504         12      IEEE
# 211  18468050  10.1109/ACCESS.2019.2895594         30      IEEE
# 212  14131500     10.1109/TAP.2013.2276414         44      IEEE
# 213         0                                       0
# 214         0                                       0
# 215         0   10.1109/JPHOT.2017.2767576         58      IEEE
# 216         0                                       0
# 217  17132608     10.1109/LPT.2017.2726139         37      IEEE
# 218         0                                       0
# 219         0                                       0
# 220         0                                       0
# 221  16774449  10.1109/ISSPIT.2016.7886039        119      IEEE
# 222         0                                       0
# 223  17581583   10.1109/JSTSP.2017.2784180        349      IEEE
# 224         0                                       0
# 225  18007396     10.1109/TWC.2018.2843786         59      IEEE
# 227  14500738     10.1109/LSP.2014.2343971       1326      IEEE
# 228         0                                       0
# 229  18526678  10.1109/ACCESS.2019.2896008         18      IEEE
# 230  17971370     10.1109/ICC.2018.8422449         21      IEEE
# 231         0                                       0
# 232  18095115     10.1109/TVT.2018.2848294        321      IEEE
# 233         0                                       0
# 234  18210767     10.1109/LSP.2018.2876019         97      IEEE
# 235   9624485     10.1109/MWC.2007.4300983        206      IEEE
# 236         0                                       0
#
#                                                    url
# 0         https://ieeexplore.ieee.org/document/8681450
# 2         https://ieeexplore.ieee.org/document/7169508
# 3         http://ieeexplore.ieee.org/document/8360103/
# 4
# 5
# 6         https://ieeexplore.ieee.org/document/8412482
# 7
# 8
# 9
# 11
# 12        https://ieeexplore.ieee.org/document/8360430
# 13
# 14        https://ieeexplore.ieee.org/document/8632974
# 15        https://ieeexplore.ieee.org/document/8542764
# 16
# 17
# 18
# 19        https://ieeexplore.ieee.org/document/8054694
# 20        https://ieeexplore.ieee.org/document/8052521
# 21        http://ieeexplore.ieee.org/document/8422586/
# 22   https://ieeexplore.ieee.org/iel7/7742/7593426/...
# 23
# 24        https://ieeexplore.ieee.org/document/8345672
# 25        https://ieeexplore.ieee.org/document/8466371
# 26        https://ieeexplore.ieee.org/document/8466360
# 27        https://ieeexplore.ieee.org/document/8291121
# 28
# 29
# 30        https://ieeexplore.ieee.org/document/8540839
# 31
# ..                                                 ...
# 206
# 207       https://ieeexplore.ieee.org/document/7900337
# 208
# 209
# 210        http://ieeexplore.ieee.org/document/7155517
# 211       https://ieeexplore.ieee.org/document/8630933
# 212       https://ieeexplore.ieee.org/document/6574205
# 213
# 214
# 215       https://ieeexplore.ieee.org/document/8089342
# 216
# 217        http://ieeexplore.ieee.org/document/7976374
# 218
# 219
# 220
# 221       https://ieeexplore.ieee.org/document/7886039
# 222
# 223       https://ieeexplore.ieee.org/document/8214233
# 224
# 225       https://ieeexplore.ieee.org/document/8383706
# 227       http://ieeexplore.ieee.org/document/6868214/
# 228
# 229       https://ieeexplore.ieee.org/document/8629874
# 230  https://ieeexplore.ieee.org/iel7/8411665/84220...
# 231
# 232       https://ieeexplore.ieee.org/document/8387468
# 233
# 234       http://ieeexplore.ieee.org/document/8492422/
# 235        http://ieeexplore.ieee.org/document/4300983
# 236
#
# [228 rows x 8 columns]

# %%
q1.save_csv_data()
