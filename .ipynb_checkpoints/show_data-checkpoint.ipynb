# %%
import os
import pandas as pd

# %%
paper1 = "6G_Wireless_Communication_Systems_Applications_Requirements_Technologies_Challenges_and_Research_Directions" 
paper1_path = os.getcwd() + "/data/" + paper1 +".csv"
paper2 = "Quantum_Machine_Learning_for_6G_Communication_Networks:_State-of-the-Art_and_Vision_for_the_Future"
paper2_path = os.getcwd() + "/data/" + paper2 +".csv"

# %%
paper1_data = pd.read_csv(paper1_path)
paper2_data = pd.read_csv(paper2_path)
pd.set_option('display.max_rows', 300)

# %%
paper1_data.head(100)
# Out:
#     Unnamed: 0                                              title  \
# 0            0  6G Wireless Communication Systems: Application...
# 1            1     Terahertz communication for vehicular networks
# 2            2   IMT traffic estimates for the years 2020 to 2030
# 3            3  Quantum machine learning for 6G communica-tion...
# 4            4     Toward 6G networks: Use cases and technologies
# 5            5  5G: A tutorial overview of standards, trials, ...
# 6            6  Oneintegrated energy efficiency proposal for 5...
# 7            7  5G backhaulchallenges and emerging research di...
# 8            8                                    What will 5G be
# 9            9                        Communications in the 6Gera
# 10          10  6G: The next frontier: From holographic mes-sa...
# 11          11  A vision of 6G wireless systems:Applications, ...
# 12          13  6G vision and requirements: Is there anyneed f...
# ...

# %%
paper2_data.head(300)
# Out:
#      Unnamed: 0                                              title  \
# 0             0  Quantum Machine Learning for 6G Communication ...
# 1             2  A survey of 5G network: Architecture andemergi...
# 2             3  Towards massive connectivity support for scal-...
# 3             4  Towards massive machinetype communications in ...
# 4             5                          Open issues and beyond 5G
# 5             6  6G vision and requirements: Is there any needf...
# 6             7                          A speculative study on 6G
# 7             8                              6G: The next frontier
# 8             9  A vision of 6Gwireless systems: Applications, ...
# 9            11  Thirty years of machine learning: The road to ...
# 10           12  Big data analytics, machine learning, and arti...
# 11           13  When machine learningmeets big data: A wireles...
# 12           14  Collaborative distributed Q-learning forRACH c...
# ...

# %%
paper1_data.sort_values(by="citations", ascending=False).head(100)
# Out:
#     Unnamed: 0                                              title  \
# 8            8                                    What will 5G be
# 59          64  Wireless communicationswith unmanned aerial ve...
# 5            5  5G: A tutorial overview of standards, trials, ...
# 11          11  A vision of 6G wireless systems:Applications, ...
# 48          53  Wireless communications through reconfigurable...
# 17          18   Theroadmap to 6G: AI empowered wireless networks
# 38          43  Wireless communications and applicationsabove ...
# 15          16  UAV communications for 5G and beyond:Recent ad...
# 4            4     Toward 6G networks: Use cases and technologies
# 7            7  5G backhaulchallenges and emerging research di...
# 28          33  6G wireless communica-tions: Vision and potent...
# 12          13  6G vision and requirements: Is there anyneed f...
# 37          42  Acomparative survey of optical wireless techno...
# ...

# %%
paper2_data.sort_values(by="citations", ascending=False).head(300)
# Out:
#      Unnamed: 0                                              title  \
# 98          103                      A survey on transfer learning
# 43           46                                    What will 5G be
# 45           48  Energy and spectral effi-ciency of very large ...
# 218         227  On the performance of non-orthogonal multiple ...
# 1             2  A survey of 5G network: Architecture andemergi...
# 47           51  Network function virtualization: State-of-the-...
# 17           19  An introduction to deep learning for the physi...
# 42           45  5G: A tutorial overview of standards, trials, ...
# 49           53                   Mobile edge com-puting: A survey
# 138         144  A device architecture for computing withquantu...
# 130         136  The capacity of the quantum channel with gener...
# 18           20  Power of deep learning for channelestimation a...
# 52           56                         5G-enabledtactile Internet
# ...
